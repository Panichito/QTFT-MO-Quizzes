# %% [markdown]
# # Mincut/Maxcut problem

# %% [markdown]
# A network is represent by a set of links shown below. Each vertex represents a person that the government can bribe (in the way mentioned in the lecture video). The price to bribe each person is also shown in the data below.
#
# Find the set of person to bribe such that the government gets the maximum amount of secret data. Then calculate the total price needed to bribe those people.
#
# Solve this problem using ILP and, if you have an access to Gurobi solver, using QUBO.

# %%
bribe_price = {0: 12,
            1: 10,
            2: 5,
            3: 4,
            4: 10,
            5: 20,
            6: 10,
            7: 5,
            8: 4,
            9: 10,
            10: 20,
            11: 10,
            12: 5,
            13: 4,
            14: 10,
            15: 20
}

link = [(0,1),
        (0,4),
        (1,5),
        (1,7),
        (1,8),
        (1,9),
        (1,14),
        (1,15),
        (2,3),
        (3,4),
        (4,6),
        (4,7),
        (4,8),
        (4,11),
        (4,13),
        (4,15),
        (5,6),
        (5,15),
        (6,7),
        (6,8),
        (7,10),
        (7,11),
        (7,14),
        (8,10),
        (9,13),
        (10,11),
        (10,12),
        (10,13),
        (10,14),
        (10,15),
        (11,12),
        (12,15),
        (13,14),
        (14,15)
        ]

# %%
# using ILP
from pulp import LpMaximize, LpMinimize, LpStatus, lpSum, LpVariable, LpProblem
import pulp
solver_list=pulp.listSolvers(onlyAvailable=True)
print(solver_list)
# Out:
# No parameters matching '_test' found
# ['GUROBI', 'PULP_CBC_CMD']

# %%
model=LpProblem(name='mincut_maxcut_problem', sense=LpMinimize)
#model=LpProblem(name='mincut_maxcut_problem', sense=LpMaximize)

# %%
x={i: LpVariable(name=f'x{i}', cat="Binary") for i in range(len(bribe_price))}
y={(link[i][0], link[i][1], j): LpVariable(name=f'y({link[i][0]},{link[i][1]})_{j}', cat="Binary") for i in range(len(link)) for j in range(0, 3)}
# y{u,v}0=neither, y{u,v}1=either, y{u,v}2=both
#y

# %%
# objective function
#model+=lpSum(x[i] for i in range(len(bribe_price)))  # not work!
#model+=lpSum(x[i]*bribe_price[i] for i in range(len(bribe_price)))

#model+=lpSum(y[(link[i][0], link[i][1], 1)]for i in range(len(link)))  # try to maximize bribe 1 node in each edge
model+=lpSum(y[(link[i][0], link[i][1], 0)]+y[(link[i][0], link[i][1], 2)] for i in range(len(link))) # minize bribe 0 & 2 nodes in each edge

# %%
# constraints
for i in range(len(link)):
    # Ye,0 + Ye,1 + Ye,2 = 1 for e in Edge
    # 1 when Y1=1, 2 when Y2=1, 0 when Y1&Y2=0
    model+=y[(link[i][0], link[i][1], 0)]+y[(link[i][0], link[i][1], 1)]+y[(link[i][0], link[i][1], 2)] == 1
    
    # Xu + Xv = Ye,1 + 2*Ye,2 for {u,v} in Edge
    model+=x[link[i][0]]+x[link[i][1]] == y[(link[i][0], link[i][1], 1)]+2*y[(link[i][0], link[i][1], 2)]
    
    #model+=x[link[i][0]]+x[link[i][1]] >= 1


# cheat (ans=7)!
#model+=lpSum(x[i] for i in range(len(bribe_price))) == 7
# maximum secret data!
#model+=lpSum(y[(link[i][0], link[i][1], 1)]+y[(link[i][0], link[i][1], 2)] for i in range(len(link))) == len(link)

# %%
status=model.solve()
status
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/panithi/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ff022cd6ec134bfa904a9bfeb8b95f96-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/ff022cd6ec134bfa904a9bfeb8b95f96-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 73 COLUMNS
# At line 616 RHS
# At line 685 BOUNDS
# At line 804 ENDATA
# Problem MODEL has 68 rows, 118 columns and 238 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 68 rows, 117 columns (117 integer (117 of which binary)) and 237 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 15 integers unsatisfied sum - 7.5
# Cbc0038I Pass   1: suminf.    7.50000 (15) obj. 0 iterations 0
# Cbc0038I Pass   2: suminf.    7.50000 (15) obj. 0 iterations 0
# Cbc0038I Pass   3: suminf.    5.00000 (10) obj. 13 iterations 24
# Cbc0038I Pass   4: suminf.    4.00000 (8) obj. 12 iterations 17
# Cbc0038I Pass   5: suminf.    4.00000 (8) obj. 12 iterations 2
# Cbc0038I Pass   6: suminf.    4.00000 (8) obj. 12 iterations 0
# Cbc0038I Pass   7: suminf.    7.00000 (14) obj. 16 iterations 27
# Cbc0038I Pass   8: suminf.    4.00000 (8) obj. 13 iterations 15
# Cbc0038I Pass   9: suminf.    4.00000 (8) obj. 13 iterations 6
# Cbc0038I Pass  10: suminf.    4.00000 (8) obj. 13 iterations 0
# Cbc0038I Pass  11: suminf.    3.00000 (6) obj. 12 iterations 12
# Cbc0038I Pass  12: suminf.    3.00000 (6) obj. 12 iterations 11
# Cbc0038I Pass  13: suminf.    3.00000 (6) obj. 12 iterations 0
# Cbc0038I Pass  14: suminf.    5.00000 (10) obj. 14 iterations 10
# Cbc0038I Pass  15: suminf.    4.00000 (8) obj. 13 iterations 6
# Cbc0038I Pass  16: suminf.    4.00000 (8) obj. 13 iterations 0
# Cbc0038I Pass  17: suminf.    4.00000 (8) obj. 13 iterations 0
# Cbc0038I Pass  18: suminf.    3.00000 (6) obj. 12 iterations 9
# Cbc0038I Pass  19: suminf.    3.00000 (6) obj. 12 iterations 7
# Cbc0038I Pass  20: suminf.    3.00000 (6) obj. 12 iterations 0
# Cbc0038I Pass  21: suminf.    6.00000 (12) obj. 17 iterations 16
# Cbc0038I Pass  22: suminf.    6.00000 (12) obj. 17 iterations 13
# Cbc0038I Pass  23: suminf.    6.00000 (12) obj. 17 iterations 1
# Cbc0038I Pass  24: suminf.    8.00000 (16) obj. 17 iterations 17
# Cbc0038I Pass  25: suminf.    7.00000 (14) obj. 16 iterations 8
# Cbc0038I Pass  26: suminf.    7.00000 (14) obj. 16 iterations 1
# Cbc0038I Pass  27: suminf.    7.00000 (14) obj. 16 iterations 1
# Cbc0038I Pass  28: suminf.    6.00000 (12) obj. 15 iterations 8
# Cbc0038I Pass  29: suminf.    6.00000 (12) obj. 15 iterations 10
# Cbc0038I Pass  30: suminf.    6.00000 (12) obj. 15 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 31 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 68 rows 117 columns, reduced to 12 rows 23 columns
# Cbc0038I Mini branch and bound improved solution from 1.79769e+308 to 8 (0.03 seconds)
# Cbc0038I Round again with cutoff of 6.30009
# Cbc0038I Pass  30: suminf.    7.50000 (15) obj. 0 iterations 0
# Cbc0038I Pass  31: suminf.    7.50000 (15) obj. 0 iterations 0
# Cbc0038I Pass  32: suminf.   11.00000 (22) obj. 4.5 iterations 20
# Cbc0038I Pass  33: suminf.   10.00000 (20) obj. 3.5 iterations 10
# Cbc0038I Pass  34: suminf.   10.00000 (20) obj. 3.5 iterations 2
# Cbc0038I Pass  35: suminf.   10.00000 (20) obj. 3.5 iterations 2
# Cbc0038I Pass  36: suminf.   11.19991 (27) obj. 6.30009 iterations 37
# Cbc0038I Pass  37: suminf.    9.50000 (24) obj. 6 iterations 14
# Cbc0038I Pass  38: suminf.    9.50000 (24) obj. 6 iterations 3
# Cbc0038I Pass  39: suminf.    9.50000 (24) obj. 6 iterations 15
# Cbc0038I Pass  40: suminf.    9.50000 (24) obj. 6 iterations 10
# Cbc0038I Pass  41: suminf.    9.50000 (24) obj. 6 iterations 9
# Cbc0038I Pass  42: suminf.   13.50000 (29) obj. 6.30009 iterations 22
# Cbc0038I Pass  43: suminf.   11.50000 (24) obj. 4.5 iterations 10
# Cbc0038I Pass  44: suminf.   11.50000 (24) obj. 4.5 iterations 3
# Cbc0038I Pass  45: suminf.   11.50000 (24) obj. 4.5 iterations 4
# Cbc0038I Pass  46: suminf.   11.50000 (23) obj. 4 iterations 10
# Cbc0038I Pass  47: suminf.   11.50000 (23) obj. 4 iterations 12
# Cbc0038I Pass  48: suminf.   11.50000 (23) obj. 4 iterations 7
# Cbc0038I Pass  49: suminf.   15.00000 (31) obj. 6.30009 iterations 16
# Cbc0038I Pass  50: suminf.   12.00000 (26) obj. 5.5 iterations 14
# Cbc0038I Pass  51: suminf.   12.00000 (26) obj. 5.5 iterations 5
# Cbc0038I Pass  52: suminf.   12.00000 (26) obj. 5.5 iterations 7
# Cbc0038I Pass  53: suminf.   12.10018 (29) obj. 6.30009 iterations 21
# Cbc0038I Pass  54: suminf.   11.50000 (26) obj. 6 iterations 11
# Cbc0038I Pass  55: suminf.   11.50000 (26) obj. 6 iterations 5
# Cbc0038I Pass  56: suminf.   11.19991 (27) obj. 6.30009 iterations 17
# Cbc0038I Pass  57: suminf.   10.10018 (27) obj. 6.30009 iterations 9
# Cbc0038I Pass  58: suminf.    9.50000 (24) obj. 6 iterations 4
# Cbc0038I Pass  59: suminf.    9.50000 (24) obj. 6 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 44 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting with objective of 8 - took 0.04 seconds
# Cbc0012I Integer solution of 8 found by feasibility pump after 0 iterations and 0 nodes (0.05 seconds)
# Cbc0038I Full problem 68 rows 117 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 7 found by DiveCoefficient after 74 iterations and 0 nodes (0.06 seconds)
# Cbc0031I 15 added rows had average density of 10.466667
# Cbc0013I At root node, 15 cuts changed objective from 0 to 7 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 7 row cuts average 11.4 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 68 row cuts average 18.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 39 row cuts average 13.2 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0001I Search completed - best objective 7, took 74 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 16 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 7
# Probing was tried 5 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 5 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 5 times and created 68 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 5 times and created 39 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.00000000
# Enumerated nodes:               0
# Total iterations:               74
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.06
# 1

# %%
model.objective.value()
# Out:
# 7.0

# %%
cnt_person=0
total_price=0
for var in model.variables():
    if var.value()==0 and var.name[0]=='x': # ILP not choose -> but we choose this least common group instead
        print(f'{var.name}: {var.value()} [{bribe_price[int(var.name[1:])]} ฿]')
        cnt_person+=1
        total_price+=bribe_price[int(var.name[1:])]
    #if var.value()==1 and var.name[0]=='y': # selected edge
    #    print(f'{var.name}: {var.value()}')

print("Number of person to bribe is", cnt_person)
print("Total price is", total_price)
# Out:
# x1: 0.0 [10 ฿]
# x10: 0.0 [20 ฿]
# x12: 0.0 [5 ฿]
# x14: 0.0 [10 ฿]
# x2: 0.0 [5 ฿]
# x4: 0.0 [10 ฿]
# x6: 0.0 [10 ฿]
# Number of person to bribe is 7
# Total price is 70

# %%
model
# Out:
# mincut_maxcut_problem:
# MINIMIZE
# 1*y(0,1)_0 + 1*y(0,1)_2 + 1*y(0,4)_0 + 1*y(0,4)_2 + 1*y(1,14)_0 + 1*y(1,14)_2 + 1*y(1,15)_0 + 1*y(1,15)_2 + 1*y(1,5)_0 + 1*y(1,5)_2 + 1*y(1,7)_0 + 1*y(1,7)_2 + 1*y(1,8)_0 + 1*y(1,8)_2 + 1*y(1,9)_0 + 1*y(1,9)_2 + 1*y(10,11)_0 + 1*y(10,11)_2 + 1*y(10,12)_0 + 1*y(10,12)_2 + 1*y(10,13)_0 + 1*y(10,13)_2 + 1*y(10,14)_0 + 1*y(10,14)_2 + 1*y(10,15)_0 + 1*y(10,15)_2 + 1*y(11,12)_0 + 1*y(11,12)_2 + 1*y(12,15)_0 + 1*y(12,15)_2 + 1*y(13,14)_0 + 1*y(13,14)_2 + 1*y(14,15)_0 + 1*y(14,15)_2 + 1*y(2,3)_0 + 1*y(2,3)_2 + 1*y(3,4)_0 + 1*y(3,4)_2 + 1*y(4,11)_0 + 1*y(4,11)_2 + 1*y(4,13)_0 + 1*y(4,13)_2 + 1*y(4,15)_0 + 1*y(4,15)_2 + 1*y(4,6)_0 + 1*y(4,6)_2 + 1*y(4,7)_0 + 1*y(4,7)_2 + 1*y(4,8)_0 + 1*y(4,8)_2 + 1*y(5,15)_0 + 1*y(5,15)_2 + 1*y(5,6)_0 + 1*y(5,6)_2 + 1*y(6,7)_0 + 1*y(6,7)_2 + 1*y(6,8)_0 + 1*y(6,8)_2 + 1*y(7,10)_0 + 1*y(7,10)_2 + 1*y(7,11)_0 + 1*y(7,11)_2 + 1*y(7,14)_0 + 1*y(7,14)_2 + 1*y(8,10)_0 + 1*y(8,10)_2 + 1*y(9,13)_0 + 1*y(9,13)_2 + 0
# SUBJECT TO
# _C1: y(0,1)_0 + y(0,1)_1 + y(0,1)_2 = 1
#
# _C2: x0 + x1 - y(0,1)_1 - 2 y(0,1)_2 = 0
#
# _C3: y(0,4)_0 + y(0,4)_1 + y(0,4)_2 = 1
#
# _C4: x0 + x4 - y(0,4)_1 - 2 y(0,4)_2 = 0
#
# _C5: y(1,5)_0 + y(1,5)_1 + y(1,5)_2 = 1
#
# _C6: x1 + x5 - y(1,5)_1 - 2 y(1,5)_2 = 0
#
# _C7: y(1,7)_0 + y(1,7)_1 + y(1,7)_2 = 1
#
# _C8: x1 + x7 - y(1,7)_1 - 2 y(1,7)_2 = 0
#
# _C9: y(1,8)_0 + y(1,8)_1 + y(1,8)_2 = 1
#
# _C10: x1 + x8 - y(1,8)_1 - 2 y(1,8)_2 = 0
#
# _C11: y(1,9)_0 + y(1,9)_1 + y(1,9)_2 = 1
#
# _C12: x1 + x9 - y(1,9)_1 - 2 y(1,9)_2 = 0
#
# _C13: y(1,14)_0 + y(1,14)_1 + y(1,14)_2 = 1
#
# _C14: x1 + x14 - y(1,14)_1 - 2 y(1,14)_2 = 0
#
# _C15: y(1,15)_0 + y(1,15)_1 + y(1,15)_2 = 1
#
# _C16: x1 + x15 - y(1,15)_1 - 2 y(1,15)_2 = 0
#
# _C17: y(2,3)_0 + y(2,3)_1 + y(2,3)_2 = 1
#
# _C18: x2 + x3 - y(2,3)_1 - 2 y(2,3)_2 = 0
#
# _C19: y(3,4)_0 + y(3,4)_1 + y(3,4)_2 = 1
#
# _C20: x3 + x4 - y(3,4)_1 - 2 y(3,4)_2 = 0
#
# _C21: y(4,6)_0 + y(4,6)_1 + y(4,6)_2 = 1
#
# _C22: x4 + x6 - y(4,6)_1 - 2 y(4,6)_2 = 0
#
# _C23: y(4,7)_0 + y(4,7)_1 + y(4,7)_2 = 1
#
# _C24: x4 + x7 - y(4,7)_1 - 2 y(4,7)_2 = 0
#
# _C25: y(4,8)_0 + y(4,8)_1 + y(4,8)_2 = 1
#
# _C26: x4 + x8 - y(4,8)_1 - 2 y(4,8)_2 = 0
#
# _C27: y(4,11)_0 + y(4,11)_1 + y(4,11)_2 = 1
#
# _C28: x11 + x4 - y(4,11)_1 - 2 y(4,11)_2 = 0
#
# _C29: y(4,13)_0 + y(4,13)_1 + y(4,13)_2 = 1
#
# _C30: x13 + x4 - y(4,13)_1 - 2 y(4,13)_2 = 0
#
# _C31: y(4,15)_0 + y(4,15)_1 + y(4,15)_2 = 1
#
# _C32: x15 + x4 - y(4,15)_1 - 2 y(4,15)_2 = 0
#
# _C33: y(5,6)_0 + y(5,6)_1 + y(5,6)_2 = 1
#
# _C34: x5 + x6 - y(5,6)_1 - 2 y(5,6)_2 = 0
#
# _C35: y(5,15)_0 + y(5,15)_1 + y(5,15)_2 = 1
#
# _C36: x15 + x5 - y(5,15)_1 - 2 y(5,15)_2 = 0
#
# _C37: y(6,7)_0 + y(6,7)_1 + y(6,7)_2 = 1
#
# _C38: x6 + x7 - y(6,7)_1 - 2 y(6,7)_2 = 0
#
# _C39: y(6,8)_0 + y(6,8)_1 + y(6,8)_2 = 1
#
# _C40: x6 + x8 - y(6,8)_1 - 2 y(6,8)_2 = 0
#
# _C41: y(7,10)_0 + y(7,10)_1 + y(7,10)_2 = 1
#
# _C42: x10 + x7 - y(7,10)_1 - 2 y(7,10)_2 = 0
#
# _C43: y(7,11)_0 + y(7,11)_1 + y(7,11)_2 = 1
#
# _C44: x11 + x7 - y(7,11)_1 - 2 y(7,11)_2 = 0
#
# _C45: y(7,14)_0 + y(7,14)_1 + y(7,14)_2 = 1
#
# _C46: x14 + x7 - y(7,14)_1 - 2 y(7,14)_2 = 0
#
# _C47: y(8,10)_0 + y(8,10)_1 + y(8,10)_2 = 1
#
# _C48: x10 + x8 - y(8,10)_1 - 2 y(8,10)_2 = 0
#
# _C49: y(9,13)_0 + y(9,13)_1 + y(9,13)_2 = 1
#
# _C50: x13 + x9 - y(9,13)_1 - 2 y(9,13)_2 = 0
#
# _C51: y(10,11)_0 + y(10,11)_1 + y(10,11)_2 = 1
#
# _C52: x10 + x11 - y(10,11)_1 - 2 y(10,11)_2 = 0
#
# _C53: y(10,12)_0 + y(10,12)_1 + y(10,12)_2 = 1
#
# _C54: x10 + x12 - y(10,12)_1 - 2 y(10,12)_2 = 0
#
# _C55: y(10,13)_0 + y(10,13)_1 + y(10,13)_2 = 1
#
# _C56: x10 + x13 - y(10,13)_1 - 2 y(10,13)_2 = 0
#
# _C57: y(10,14)_0 + y(10,14)_1 + y(10,14)_2 = 1
#
# _C58: x10 + x14 - y(10,14)_1 - 2 y(10,14)_2 = 0
#
# _C59: y(10,15)_0 + y(10,15)_1 + y(10,15)_2 = 1
#
# _C60: x10 + x15 - y(10,15)_1 - 2 y(10,15)_2 = 0
#
# _C61: y(11,12)_0 + y(11,12)_1 + y(11,12)_2 = 1
#
# _C62: x11 + x12 - y(11,12)_1 - 2 y(11,12)_2 = 0
#
# _C63: y(12,15)_0 + y(12,15)_1 + y(12,15)_2 = 1
#
# _C64: x12 + x15 - y(12,15)_1 - 2 y(12,15)_2 = 0
#
# _C65: y(13,14)_0 + y(13,14)_1 + y(13,14)_2 = 1
#
# _C66: x13 + x14 - y(13,14)_1 - 2 y(13,14)_2 = 0
#
# _C67: y(14,15)_0 + y(14,15)_1 + y(14,15)_2 = 1
#
# _C68: x14 + x15 - y(14,15)_1 - 2 y(14,15)_2 = 0
#
# VARIABLES
# 0 <= x0 <= 1 Integer
# 0 <= x1 <= 1 Integer
# 0 <= x10 <= 1 Integer
# 0 <= x11 <= 1 Integer
# 0 <= x12 <= 1 Integer
# 0 <= x13 <= 1 Integer
# 0 <= x14 <= 1 Integer
# 0 <= x15 <= 1 Integer
# 0 <= x2 <= 1 Integer
# 0 <= x3 <= 1 Integer
# 0 <= x4 <= 1 Integer
# 0 <= x5 <= 1 Integer
# 0 <= x6 <= 1 Integer
# 0 <= x7 <= 1 Integer
# 0 <= x8 <= 1 Integer
# 0 <= x9 <= 1 Integer
# 0 <= y(0,1)_0 <= 1 Integer
# 0 <= y(0,1)_1 <= 1 Integer
# 0 <= y(0,1)_2 <= 1 Integer
# 0 <= y(0,4)_0 <= 1 Integer
# 0 <= y(0,4)_1 <= 1 Integer
# 0 <= y(0,4)_2 <= 1 Integer
# 0 <= y(1,14)_0 <= 1 Integer
# 0 <= y(1,14)_1 <= 1 Integer
# 0 <= y(1,14)_2 <= 1 Integer
# 0 <= y(1,15)_0 <= 1 Integer
# 0 <= y(1,15)_1 <= 1 Integer
# 0 <= y(1,15)_2 <= 1 Integer
# 0 <= y(1,5)_0 <= 1 Integer
# 0 <= y(1,5)_1 <= 1 Integer
# 0 <= y(1,5)_2 <= 1 Integer
# 0 <= y(1,7)_0 <= 1 Integer
# 0 <= y(1,7)_1 <= 1 Integer
# 0 <= y(1,7)_2 <= 1 Integer
# 0 <= y(1,8)_0 <= 1 Integer
# 0 <= y(1,8)_1 <= 1 Integer
# 0 <= y(1,8)_2 <= 1 Integer
# 0 <= y(1,9)_0 <= 1 Integer
# 0 <= y(1,9)_1 <= 1 Integer
# 0 <= y(1,9)_2 <= 1 Integer
# 0 <= y(10,11)_0 <= 1 Integer
# 0 <= y(10,11)_1 <= 1 Integer
# 0 <= y(10,11)_2 <= 1 Integer
# 0 <= y(10,12)_0 <= 1 Integer
# 0 <= y(10,12)_1 <= 1 Integer
# 0 <= y(10,12)_2 <= 1 Integer
# 0 <= y(10,13)_0 <= 1 Integer
# 0 <= y(10,13)_1 <= 1 Integer
# 0 <= y(10,13)_2 <= 1 Integer
# 0 <= y(10,14)_0 <= 1 Integer
# 0 <= y(10,14)_1 <= 1 Integer
# 0 <= y(10,14)_2 <= 1 Integer
# 0 <= y(10,15)_0 <= 1 Integer
# 0 <= y(10,15)_1 <= 1 Integer
# 0 <= y(10,15)_2 <= 1 Integer
# 0 <= y(11,12)_0 <= 1 Integer
# 0 <= y(11,12)_1 <= 1 Integer
# 0 <= y(11,12)_2 <= 1 Integer
# 0 <= y(12,15)_0 <= 1 Integer
# 0 <= y(12,15)_1 <= 1 Integer
# 0 <= y(12,15)_2 <= 1 Integer
# 0 <= y(13,14)_0 <= 1 Integer
# 0 <= y(13,14)_1 <= 1 Integer
# 0 <= y(13,14)_2 <= 1 Integer
# 0 <= y(14,15)_0 <= 1 Integer
# 0 <= y(14,15)_1 <= 1 Integer
# 0 <= y(14,15)_2 <= 1 Integer
# 0 <= y(2,3)_0 <= 1 Integer
# 0 <= y(2,3)_1 <= 1 Integer
# 0 <= y(2,3)_2 <= 1 Integer
# 0 <= y(3,4)_0 <= 1 Integer
# 0 <= y(3,4)_1 <= 1 Integer
# 0 <= y(3,4)_2 <= 1 Integer
# 0 <= y(4,11)_0 <= 1 Integer
# 0 <= y(4,11)_1 <= 1 Integer
# 0 <= y(4,11)_2 <= 1 Integer
# 0 <= y(4,13)_0 <= 1 Integer
# 0 <= y(4,13)_1 <= 1 Integer
# 0 <= y(4,13)_2 <= 1 Integer
# 0 <= y(4,15)_0 <= 1 Integer
# 0 <= y(4,15)_1 <= 1 Integer
# 0 <= y(4,15)_2 <= 1 Integer
# 0 <= y(4,6)_0 <= 1 Integer
# 0 <= y(4,6)_1 <= 1 Integer
# 0 <= y(4,6)_2 <= 1 Integer
# 0 <= y(4,7)_0 <= 1 Integer
# 0 <= y(4,7)_1 <= 1 Integer
# 0 <= y(4,7)_2 <= 1 Integer
# 0 <= y(4,8)_0 <= 1 Integer
# 0 <= y(4,8)_1 <= 1 Integer
# 0 <= y(4,8)_2 <= 1 Integer
# 0 <= y(5,15)_0 <= 1 Integer
# 0 <= y(5,15)_1 <= 1 Integer
# 0 <= y(5,15)_2 <= 1 Integer
# 0 <= y(5,6)_0 <= 1 Integer
# 0 <= y(5,6)_1 <= 1 Integer
# 0 <= y(5,6)_2 <= 1 Integer
# 0 <= y(6,7)_0 <= 1 Integer
# 0 <= y(6,7)_1 <= 1 Integer
# 0 <= y(6,7)_2 <= 1 Integer
# 0 <= y(6,8)_0 <= 1 Integer
# 0 <= y(6,8)_1 <= 1 Integer
# 0 <= y(6,8)_2 <= 1 Integer
# 0 <= y(7,10)_0 <= 1 Integer
# 0 <= y(7,10)_1 <= 1 Integer
# 0 <= y(7,10)_2 <= 1 Integer
# 0 <= y(7,11)_0 <= 1 Integer
# 0 <= y(7,11)_1 <= 1 Integer
# 0 <= y(7,11)_2 <= 1 Integer
# 0 <= y(7,14)_0 <= 1 Integer
# 0 <= y(7,14)_1 <= 1 Integer
# 0 <= y(7,14)_2 <= 1 Integer
# 0 <= y(8,10)_0 <= 1 Integer
# 0 <= y(8,10)_1 <= 1 Integer
# 0 <= y(8,10)_2 <= 1 Integer
# 0 <= y(9,13)_0 <= 1 Integer
# 0 <= y(9,13)_1 <= 1 Integer
# 0 <= y(9,13)_2 <= 1 Integer
