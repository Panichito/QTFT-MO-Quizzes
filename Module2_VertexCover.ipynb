# %% [markdown]
# # Vortex cover all but k edges
#
# Expanding upon the vertex cover problem we discussed in the lab, we would like to find the smallest set of vertices that covers all edges in the graph but $k$ edges.
#
# For example, if the graph has a total of 30 edges, and let $k = 4$, we would like to find the set of vertices that covers 26 edges in the graph. The 4 uncovered edges can be any edge.
#
# Find the number of vortex needed to cover all edges but 4 edges for the following graph.

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable, LpMinimize
import pulp

# %%
G = nx.watts_strogatz_graph(n = 30, k = 10, p = 0.4, seed = 2002)
total_node=30

# %%
model=LpProblem(name='vortex_cover_all_but_k', sense=LpMinimize)
k=4

# %%
x={i: LpVariable(name=f'n{i}', cat='Binary') for i in range(total_node)}
#print(x)
y={e: LpVariable(name=f'e{e}', cat='Binary') for index, e in enumerate(G.edges)}
#print(y)

# %%
# constraints
model+=lpSum(y[e] for e in G.edges)==len(G.edges)-k
for e in G.edges():
    model+=(x[e[0]]+x[e[1]] >= y[(e[0], e[1])], f'constraint{e}')

# %%
# objective function
#model+=lpSum(y[e] for e in G.edges)
model+=lpSum(x[i] for i in range(total_node))
model
# Out:
# vortex_cover_all_but_k:
# MINIMIZE
# 1*n0 + 1*n1 + 1*n10 + 1*n11 + 1*n12 + 1*n13 + 1*n14 + 1*n15 + 1*n16 + 1*n17 + 1*n18 + 1*n19 + 1*n2 + 1*n20 + 1*n21 + 1*n22 + 1*n23 + 1*n24 + 1*n25 + 1*n26 + 1*n27 + 1*n28 + 1*n29 + 1*n3 + 1*n4 + 1*n5 + 1*n6 + 1*n7 + 1*n8 + 1*n9 + 0
# SUBJECT TO
# _C1: e(0,_1) + e(0,_10) + e(0,_13) + e(0,_14) + e(0,_19) + e(0,_2) + e(0,_25)
#  + e(0,_26) + e(0,_29) + e(0,_3) + e(0,_7) + e(1,_11) + e(1,_15) + e(1,_17)
#  + e(1,_2) + e(1,_21) + e(1,_26) + e(1,_27) + e(1,_28) + e(1,_29) + e(1,_3)
#  + e(1,_4) + e(1,_5) + e(10,_12) + e(10,_29) + e(11,_12) + e(11,_13)
#  + e(11,_15) + e(11,_19) + e(11,_28) + e(11,_29) + e(12,_13) + e(12,_15)
#  + e(12,_16) + e(12,_17) + e(12,_20) + e(12,_23) + e(13,_14) + e(13,_15)
#  + e(13,_17) + e(13,_18) + e(14,_15) + e(14,_16) + e(14,_17) + e(14,_18)
#  + e(14,_20) + e(15,_16) + e(15,_17) + e(15,_23) + e(15,_26) + e(15,_28)
#  + e(16,_17) + e(16,_19) + e(16,_21) + e(16,_23) + e(16,_26) + e(17,_18)
#  + e(17,_19) + e(17,_21) + e(18,_19) + e(18,_20) + e(18,_21) + e(18,_23)
#  + e(18,_24) + e(19,_20) + e(19,_24) + e(19,_27) + e(19,_29) + e(2,_10)
#  + e(2,_27) + e(2,_28) + e(2,_29) + e(2,_3) + e(2,_4) + e(2,_5) + e(2,_6)
#  + e(2,_7) + e(2,_8) + e(20,_21) + e(20,_22) + e(20,_25) + e(20,_27)
#  + e(21,_22) + e(21,_24) + e(21,_26) + e(21,_27) + e(22,_23) + e(22,_24)
#  + e(22,_25) + e(22,_26) + e(22,_27) + e(22,_29) + e(23,_24) + e(23,_27)
#  + e(23,_28) + e(24,_26) + e(24,_27) + e(24,_29) + e(25,_26) + e(25,_27)
#  + e(25,_28) + e(26,_27) + e(26,_28) + e(27,_29) + e(3,_23) + e(3,_28)
#  + e(3,_4) + e(3,_5) + e(3,_6) + e(3,_7) + e(4,_10) + e(4,_17) + e(4,_24)
#  + e(4,_28) + e(4,_5) + e(4,_8) + e(5,_10) + e(5,_11) + e(5,_15) + e(5,_17)
#  + e(5,_20) + e(5,_21) + e(5,_6) + e(5,_7) + e(5,_8) + e(6,_11) + e(6,_22)
#  + e(6,_27) + e(6,_7) + e(6,_8) + e(6,_9) + e(7,_10) + e(7,_11) + e(7,_15)
#  + e(7,_16) + e(7,_24) + e(7,_26) + e(7,_9) + e(8,_11) + e(8,_13) + e(8,_17)
#  + e(8,_18) + e(8,_25) + e(8,_29) + e(9,_11) + e(9,_13) + e(9,_14) + e(9,_24)
#  + e(9,_28) + e(9,_29) = 146
#
# constraint(0,_1): - e(0,_1) + n0 + n1 >= 0
#
# constraint(0,_29): - e(0,_29) + n0 + n29 >= 0
#
# constraint(0,_2): - e(0,_2) + n0 + n2 >= 0
#
# constraint(0,_3): - e(0,_3) + n0 + n3 >= 0
#
# constraint(0,_26): - e(0,_26) + n0 + n26 >= 0
#
# constraint(0,_25): - e(0,_25) + n0 + n25 >= 0
#
# constraint(0,_10): - e(0,_10) + n0 + n10 >= 0
#
# constraint(0,_14): - e(0,_14) + n0 + n14 >= 0
#
# constraint(0,_19): - e(0,_19) + n0 + n19 >= 0
#
# constraint(0,_13): - e(0,_13) + n0 + n13 >= 0
#
# constraint(0,_7): - e(0,_7) + n0 + n7 >= 0
#
# constraint(1,_2): - e(1,_2) + n1 + n2 >= 0
#
# constraint(1,_3): - e(1,_3) + n1 + n3 >= 0
#
# constraint(1,_4): - e(1,_4) + n1 + n4 >= 0
#
# constraint(1,_28): - e(1,_28) + n1 + n28 >= 0
#
# constraint(1,_5): - e(1,_5) + n1 + n5 >= 0
#
# constraint(1,_26): - e(1,_26) + n1 + n26 >= 0
#
# constraint(1,_11): - e(1,_11) + n1 + n11 >= 0
#
# constraint(1,_21): - e(1,_21) + n1 + n21 >= 0
#
# constraint(1,_15): - e(1,_15) + n1 + n15 >= 0
#
# constraint(1,_29): - e(1,_29) + n1 + n29 >= 0
#
# constraint(1,_27): - e(1,_27) + n1 + n27 >= 0
#
# constraint(1,_17): - e(1,_17) + n1 + n17 >= 0
#
# constraint(2,_3): - e(2,_3) + n2 + n3 >= 0
#
# constraint(2,_4): - e(2,_4) + n2 + n4 >= 0
#
# constraint(2,_5): - e(2,_5) + n2 + n5 >= 0
#
# constraint(2,_29): - e(2,_29) + n2 + n29 >= 0
#
# constraint(2,_6): - e(2,_6) + n2 + n6 >= 0
#
# constraint(2,_28): - e(2,_28) + n2 + n28 >= 0
#
# constraint(2,_7): - e(2,_7) + n2 + n7 >= 0
#
# constraint(2,_27): - e(2,_27) + n2 + n27 >= 0
#
# constraint(2,_8): - e(2,_8) + n2 + n8 >= 0
#
# constraint(2,_10): - e(2,_10) + n10 + n2 >= 0
#
# constraint(3,_4): - e(3,_4) + n3 + n4 >= 0
#
# constraint(3,_5): - e(3,_5) + n3 + n5 >= 0
#
# constraint(3,_6): - e(3,_6) + n3 + n6 >= 0
#
# constraint(3,_7): - e(3,_7) + n3 + n7 >= 0
#
# constraint(3,_28): - e(3,_28) + n28 + n3 >= 0
#
# constraint(3,_23): - e(3,_23) + n23 + n3 >= 0
#
# constraint(4,_5): - e(4,_5) + n4 + n5 >= 0
#
# constraint(4,_8): - e(4,_8) + n4 + n8 >= 0
#
# constraint(4,_17): - e(4,_17) + n17 + n4 >= 0
#
# constraint(4,_28): - e(4,_28) + n28 + n4 >= 0
#
# constraint(4,_24): - e(4,_24) + n24 + n4 >= 0
#
# constraint(4,_10): - e(4,_10) + n10 + n4 >= 0
#
# constraint(5,_6): - e(5,_6) + n5 + n6 >= 0
#
# constraint(5,_8): - e(5,_8) + n5 + n8 >= 0
#
# constraint(5,_10): - e(5,_10) + n10 + n5 >= 0
#
# constraint(5,_21): - e(5,_21) + n21 + n5 >= 0
#
# constraint(5,_7): - e(5,_7) + n5 + n7 >= 0
#
# constraint(5,_17): - e(5,_17) + n17 + n5 >= 0
#
# constraint(5,_20): - e(5,_20) + n20 + n5 >= 0
#
# constraint(5,_11): - e(5,_11) + n11 + n5 >= 0
#
# constraint(5,_15): - e(5,_15) + n15 + n5 >= 0
#
# constraint(6,_7): - e(6,_7) + n6 + n7 >= 0
#
# constraint(6,_8): - e(6,_8) + n6 + n8 >= 0
#
# constraint(6,_9): - e(6,_9) + n6 + n9 >= 0
#
# constraint(6,_11): - e(6,_11) + n11 + n6 >= 0
#
# constraint(6,_27): - e(6,_27) + n27 + n6 >= 0
#
# constraint(6,_22): - e(6,_22) + n22 + n6 >= 0
#
# constraint(7,_10): - e(7,_10) + n10 + n7 >= 0
#
# constraint(7,_11): - e(7,_11) + n11 + n7 >= 0
#
# constraint(7,_16): - e(7,_16) + n16 + n7 >= 0
#
# constraint(7,_9): - e(7,_9) + n7 + n9 >= 0
#
# constraint(7,_15): - e(7,_15) + n15 + n7 >= 0
#
# constraint(7,_24): - e(7,_24) + n24 + n7 >= 0
#
# constraint(7,_26): - e(7,_26) + n26 + n7 >= 0
#
# constraint(8,_11): - e(8,_11) + n11 + n8 >= 0
#
# constraint(8,_13): - e(8,_13) + n13 + n8 >= 0
#
# constraint(8,_25): - e(8,_25) + n25 + n8 >= 0
#
# constraint(8,_17): - e(8,_17) + n17 + n8 >= 0
#
# constraint(8,_29): - e(8,_29) + n29 + n8 >= 0
#
# constraint(8,_18): - e(8,_18) + n18 + n8 >= 0
#
# constraint(9,_11): - e(9,_11) + n11 + n9 >= 0
#
# constraint(9,_13): - e(9,_13) + n13 + n9 >= 0
#
# constraint(9,_14): - e(9,_14) + n14 + n9 >= 0
#
# constraint(9,_24): - e(9,_24) + n24 + n9 >= 0
#
# constraint(9,_28): - e(9,_28) + n28 + n9 >= 0
#
# constraint(9,_29): - e(9,_29) + n29 + n9 >= 0
#
# constraint(10,_12): - e(10,_12) + n10 + n12 >= 0
#
# constraint(10,_29): - e(10,_29) + n10 + n29 >= 0
#
# constraint(11,_12): - e(11,_12) + n11 + n12 >= 0
#
# constraint(11,_15): - e(11,_15) + n11 + n15 >= 0
#
# constraint(11,_28): - e(11,_28) + n11 + n28 >= 0
#
# constraint(11,_13): - e(11,_13) + n11 + n13 >= 0
#
# constraint(11,_19): - e(11,_19) + n11 + n19 >= 0
#
# constraint(11,_29): - e(11,_29) + n11 + n29 >= 0
#
# constraint(12,_13): - e(12,_13) + n12 + n13 >= 0
#
# constraint(12,_15): - e(12,_15) + n12 + n15 >= 0
#
# constraint(12,_16): - e(12,_16) + n12 + n16 >= 0
#
# constraint(12,_17): - e(12,_17) + n12 + n17 >= 0
#
# constraint(12,_20): - e(12,_20) + n12 + n20 >= 0
#
# constraint(12,_23): - e(12,_23) + n12 + n23 >= 0
#
# constraint(13,_14): - e(13,_14) + n13 + n14 >= 0
#
# constraint(13,_15): - e(13,_15) + n13 + n15 >= 0
#
# constraint(13,_17): - e(13,_17) + n13 + n17 >= 0
#
# constraint(13,_18): - e(13,_18) + n13 + n18 >= 0
#
# constraint(14,_15): - e(14,_15) + n14 + n15 >= 0
#
# constraint(14,_17): - e(14,_17) + n14 + n17 >= 0
#
# constraint(14,_18): - e(14,_18) + n14 + n18 >= 0
#
# constraint(14,_20): - e(14,_20) + n14 + n20 >= 0
#
# constraint(14,_16): - e(14,_16) + n14 + n16 >= 0
#
# constraint(15,_16): - e(15,_16) + n15 + n16 >= 0
#
# constraint(15,_17): - e(15,_17) + n15 + n17 >= 0
#
# constraint(15,_23): - e(15,_23) + n15 + n23 >= 0
#
# constraint(15,_28): - e(15,_28) + n15 + n28 >= 0
#
# constraint(15,_26): - e(15,_26) + n15 + n26 >= 0
#
# constraint(16,_17): - e(16,_17) + n16 + n17 >= 0
#
# constraint(16,_19): - e(16,_19) + n16 + n19 >= 0
#
# constraint(16,_21): - e(16,_21) + n16 + n21 >= 0
#
# constraint(16,_23): - e(16,_23) + n16 + n23 >= 0
#
# constraint(16,_26): - e(16,_26) + n16 + n26 >= 0
#
# constraint(17,_18): - e(17,_18) + n17 + n18 >= 0
#
# constraint(17,_19): - e(17,_19) + n17 + n19 >= 0
#
# constraint(17,_21): - e(17,_21) + n17 + n21 >= 0
#
# constraint(18,_19): - e(18,_19) + n18 + n19 >= 0
#
# constraint(18,_20): - e(18,_20) + n18 + n20 >= 0
#
# constraint(18,_21): - e(18,_21) + n18 + n21 >= 0
#
# constraint(18,_23): - e(18,_23) + n18 + n23 >= 0
#
# constraint(18,_24): - e(18,_24) + n18 + n24 >= 0
#
# constraint(19,_20): - e(19,_20) + n19 + n20 >= 0
#
# constraint(19,_24): - e(19,_24) + n19 + n24 >= 0
#
# constraint(19,_27): - e(19,_27) + n19 + n27 >= 0
#
# constraint(19,_29): - e(19,_29) + n19 + n29 >= 0
#
# constraint(20,_21): - e(20,_21) + n20 + n21 >= 0
#
# constraint(20,_22): - e(20,_22) + n20 + n22 >= 0
#
# constraint(20,_25): - e(20,_25) + n20 + n25 >= 0
#
# constraint(20,_27): - e(20,_27) + n20 + n27 >= 0
#
# constraint(21,_24): - e(21,_24) + n21 + n24 >= 0
#
# constraint(21,_26): - e(21,_26) + n21 + n26 >= 0
#
# constraint(21,_27): - e(21,_27) + n21 + n27 >= 0
#
# constraint(21,_22): - e(21,_22) + n21 + n22 >= 0
#
# constraint(22,_23): - e(22,_23) + n22 + n23 >= 0
#
# constraint(22,_24): - e(22,_24) + n22 + n24 >= 0
#
# constraint(22,_25): - e(22,_25) + n22 + n25 >= 0
#
# constraint(22,_26): - e(22,_26) + n22 + n26 >= 0
#
# constraint(22,_27): - e(22,_27) + n22 + n27 >= 0
#
# constraint(22,_29): - e(22,_29) + n22 + n29 >= 0
#
# constraint(23,_24): - e(23,_24) + n23 + n24 >= 0
#
# constraint(23,_27): - e(23,_27) + n23 + n27 >= 0
#
# constraint(23,_28): - e(23,_28) + n23 + n28 >= 0
#
# constraint(24,_26): - e(24,_26) + n24 + n26 >= 0
#
# constraint(24,_27): - e(24,_27) + n24 + n27 >= 0
#
# constraint(24,_29): - e(24,_29) + n24 + n29 >= 0
#
# constraint(25,_27): - e(25,_27) + n25 + n27 >= 0
#
# constraint(25,_28): - e(25,_28) + n25 + n28 >= 0
#
# constraint(25,_26): - e(25,_26) + n25 + n26 >= 0
#
# constraint(26,_27): - e(26,_27) + n26 + n27 >= 0
#
# constraint(26,_28): - e(26,_28) + n26 + n28 >= 0
#
# constraint(27,_29): - e(27,_29) + n27 + n29 >= 0
#
# VARIABLES
# 0 <= e(0,_1) <= 1 Integer
# 0 <= e(0,_10) <= 1 Integer
# 0 <= e(0,_13) <= 1 Integer
# 0 <= e(0,_14) <= 1 Integer
# 0 <= e(0,_19) <= 1 Integer
# 0 <= e(0,_2) <= 1 Integer
# 0 <= e(0,_25) <= 1 Integer
# 0 <= e(0,_26) <= 1 Integer
# 0 <= e(0,_29) <= 1 Integer
# 0 <= e(0,_3) <= 1 Integer
# 0 <= e(0,_7) <= 1 Integer
# 0 <= e(1,_11) <= 1 Integer
# 0 <= e(1,_15) <= 1 Integer
# 0 <= e(1,_17) <= 1 Integer
# 0 <= e(1,_2) <= 1 Integer
# 0 <= e(1,_21) <= 1 Integer
# 0 <= e(1,_26) <= 1 Integer
# 0 <= e(1,_27) <= 1 Integer
# 0 <= e(1,_28) <= 1 Integer
# 0 <= e(1,_29) <= 1 Integer
# 0 <= e(1,_3) <= 1 Integer
# 0 <= e(1,_4) <= 1 Integer
# 0 <= e(1,_5) <= 1 Integer
# 0 <= e(10,_12) <= 1 Integer
# 0 <= e(10,_29) <= 1 Integer
# 0 <= e(11,_12) <= 1 Integer
# 0 <= e(11,_13) <= 1 Integer
# 0 <= e(11,_15) <= 1 Integer
# 0 <= e(11,_19) <= 1 Integer
# 0 <= e(11,_28) <= 1 Integer
# 0 <= e(11,_29) <= 1 Integer
# 0 <= e(12,_13) <= 1 Integer
# 0 <= e(12,_15) <= 1 Integer
# 0 <= e(12,_16) <= 1 Integer
# 0 <= e(12,_17) <= 1 Integer
# 0 <= e(12,_20) <= 1 Integer
# 0 <= e(12,_23) <= 1 Integer
# 0 <= e(13,_14) <= 1 Integer
# 0 <= e(13,_15) <= 1 Integer
# 0 <= e(13,_17) <= 1 Integer
# 0 <= e(13,_18) <= 1 Integer
# 0 <= e(14,_15) <= 1 Integer
# 0 <= e(14,_16) <= 1 Integer
# 0 <= e(14,_17) <= 1 Integer
# 0 <= e(14,_18) <= 1 Integer
# 0 <= e(14,_20) <= 1 Integer
# 0 <= e(15,_16) <= 1 Integer
# 0 <= e(15,_17) <= 1 Integer
# 0 <= e(15,_23) <= 1 Integer
# 0 <= e(15,_26) <= 1 Integer
# 0 <= e(15,_28) <= 1 Integer
# 0 <= e(16,_17) <= 1 Integer
# 0 <= e(16,_19) <= 1 Integer
# 0 <= e(16,_21) <= 1 Integer
# 0 <= e(16,_23) <= 1 Integer
# 0 <= e(16,_26) <= 1 Integer
# 0 <= e(17,_18) <= 1 Integer
# 0 <= e(17,_19) <= 1 Integer
# 0 <= e(17,_21) <= 1 Integer
# 0 <= e(18,_19) <= 1 Integer
# 0 <= e(18,_20) <= 1 Integer
# 0 <= e(18,_21) <= 1 Integer
# 0 <= e(18,_23) <= 1 Integer
# 0 <= e(18,_24) <= 1 Integer
# 0 <= e(19,_20) <= 1 Integer
# 0 <= e(19,_24) <= 1 Integer
# 0 <= e(19,_27) <= 1 Integer
# 0 <= e(19,_29) <= 1 Integer
# 0 <= e(2,_10) <= 1 Integer
# 0 <= e(2,_27) <= 1 Integer
# 0 <= e(2,_28) <= 1 Integer
# 0 <= e(2,_29) <= 1 Integer
# 0 <= e(2,_3) <= 1 Integer
# 0 <= e(2,_4) <= 1 Integer
# 0 <= e(2,_5) <= 1 Integer
# 0 <= e(2,_6) <= 1 Integer
# 0 <= e(2,_7) <= 1 Integer
# 0 <= e(2,_8) <= 1 Integer
# 0 <= e(20,_21) <= 1 Integer
# 0 <= e(20,_22) <= 1 Integer
# 0 <= e(20,_25) <= 1 Integer
# 0 <= e(20,_27) <= 1 Integer
# 0 <= e(21,_22) <= 1 Integer
# 0 <= e(21,_24) <= 1 Integer
# 0 <= e(21,_26) <= 1 Integer
# 0 <= e(21,_27) <= 1 Integer
# 0 <= e(22,_23) <= 1 Integer
# 0 <= e(22,_24) <= 1 Integer
# 0 <= e(22,_25) <= 1 Integer
# 0 <= e(22,_26) <= 1 Integer
# 0 <= e(22,_27) <= 1 Integer
# 0 <= e(22,_29) <= 1 Integer
# 0 <= e(23,_24) <= 1 Integer
# 0 <= e(23,_27) <= 1 Integer
# 0 <= e(23,_28) <= 1 Integer
# 0 <= e(24,_26) <= 1 Integer
# 0 <= e(24,_27) <= 1 Integer
# 0 <= e(24,_29) <= 1 Integer
# 0 <= e(25,_26) <= 1 Integer
# 0 <= e(25,_27) <= 1 Integer
# 0 <= e(25,_28) <= 1 Integer
# 0 <= e(26,_27) <= 1 Integer
# 0 <= e(26,_28) <= 1 Integer
# 0 <= e(27,_29) <= 1 Integer
# 0 <= e(3,_23) <= 1 Integer
# 0 <= e(3,_28) <= 1 Integer
# 0 <= e(3,_4) <= 1 Integer
# 0 <= e(3,_5) <= 1 Integer
# 0 <= e(3,_6) <= 1 Integer
# 0 <= e(3,_7) <= 1 Integer
# 0 <= e(4,_10) <= 1 Integer
# 0 <= e(4,_17) <= 1 Integer
# 0 <= e(4,_24) <= 1 Integer
# 0 <= e(4,_28) <= 1 Integer
# 0 <= e(4,_5) <= 1 Integer
# 0 <= e(4,_8) <= 1 Integer
# 0 <= e(5,_10) <= 1 Integer
# 0 <= e(5,_11) <= 1 Integer
# 0 <= e(5,_15) <= 1 Integer
# 0 <= e(5,_17) <= 1 Integer
# 0 <= e(5,_20) <= 1 Integer
# 0 <= e(5,_21) <= 1 Integer
# 0 <= e(5,_6) <= 1 Integer
# 0 <= e(5,_7) <= 1 Integer
# 0 <= e(5,_8) <= 1 Integer
# 0 <= e(6,_11) <= 1 Integer
# 0 <= e(6,_22) <= 1 Integer
# 0 <= e(6,_27) <= 1 Integer
# 0 <= e(6,_7) <= 1 Integer
# 0 <= e(6,_8) <= 1 Integer
# 0 <= e(6,_9) <= 1 Integer
# 0 <= e(7,_10) <= 1 Integer
# 0 <= e(7,_11) <= 1 Integer
# 0 <= e(7,_15) <= 1 Integer
# 0 <= e(7,_16) <= 1 Integer
# 0 <= e(7,_24) <= 1 Integer
# 0 <= e(7,_26) <= 1 Integer
# 0 <= e(7,_9) <= 1 Integer
# 0 <= e(8,_11) <= 1 Integer
# 0 <= e(8,_13) <= 1 Integer
# 0 <= e(8,_17) <= 1 Integer
# 0 <= e(8,_18) <= 1 Integer
# 0 <= e(8,_25) <= 1 Integer
# 0 <= e(8,_29) <= 1 Integer
# 0 <= e(9,_11) <= 1 Integer
# 0 <= e(9,_13) <= 1 Integer
# 0 <= e(9,_14) <= 1 Integer
# 0 <= e(9,_24) <= 1 Integer
# 0 <= e(9,_28) <= 1 Integer
# 0 <= e(9,_29) <= 1 Integer
# 0 <= n0 <= 1 Integer
# 0 <= n1 <= 1 Integer
# 0 <= n10 <= 1 Integer
# 0 <= n11 <= 1 Integer
# 0 <= n12 <= 1 Integer
# 0 <= n13 <= 1 Integer
# 0 <= n14 <= 1 Integer
# 0 <= n15 <= 1 Integer
# 0 <= n16 <= 1 Integer
# 0 <= n17 <= 1 Integer
# 0 <= n18 <= 1 Integer
# 0 <= n19 <= 1 Integer
# 0 <= n2 <= 1 Integer
# 0 <= n20 <= 1 Integer
# 0 <= n21 <= 1 Integer
# 0 <= n22 <= 1 Integer
# 0 <= n23 <= 1 Integer
# 0 <= n24 <= 1 Integer
# 0 <= n25 <= 1 Integer
# 0 <= n26 <= 1 Integer
# 0 <= n27 <= 1 Integer
# 0 <= n28 <= 1 Integer
# 0 <= n29 <= 1 Integer
# 0 <= n3 <= 1 Integer
# 0 <= n4 <= 1 Integer
# 0 <= n5 <= 1 Integer
# 0 <= n6 <= 1 Integer
# 0 <= n7 <= 1 Integer
# 0 <= n8 <= 1 Integer
# 0 <= n9 <= 1 Integer

# %%
model.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/panithi/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4f372fc26ddb4adc8ba5293c0c9bba47-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/4f372fc26ddb4adc8ba5293c0c9bba47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 156 COLUMNS
# At line 1147 RHS
# At line 1299 BOUNDS
# At line 1480 ENDATA
# Problem MODEL has 151 rows, 180 columns and 600 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 14.4286 - 0.00 seconds
# Cgl0004I processed model has 151 rows, 180 columns (180 integer (180 of which binary)) and 600 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0045I 30 integer variables out of 180 objects (180 integer) have cost of 1 - high priority
# Cbc0045I branch on satisfied N create fake objective Y random cost Y
# Cbc0038I Initial state - 43 integers unsatisfied sum - 18.4286
# Cbc0038I Pass   1: suminf.   17.50000 (35) obj. 14.5 iterations 119
# Cbc0038I Pass   2: suminf.    4.50000 (11) obj. 24.8333 iterations 84
# Cbc0038I Pass   3: suminf.    4.00000 (8) obj. 25 iterations 7
# Cbc0038I Pass   4: suminf.    0.00000 (0) obj. 27 iterations 9
# Cbc0038I Solution found of 27
# Cbc0038I Rounding solution of 24 is better than previous of 27
#
# Cbc0038I Before mini branch and bound, 129 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 151 rows 180 columns, reduced to 151 rows 51 columns - 13 fixed gives 72, 34 - ok now
# Cbc0038I Full problem 151 rows 180 columns, reduced to 72 rows 34 columns
# Cbc0038I Mini branch and bound improved solution from 24 to 21 (0.03 seconds)
# Cbc0038I Round again with cutoff of 19.4429
# Cbc0038I Pass   5: suminf.   17.50000 (35) obj. 14.5 iterations 0
# Cbc0038I Pass   6: suminf.   14.50000 (29) obj. 17.5 iterations 91
# Cbc0038I Pass   7: suminf.   14.50000 (29) obj. 17.5 iterations 69
# Cbc0038I Pass   8: suminf.   12.35705 (37) obj. 19.4429 iterations 68
# Cbc0038I Pass   9: suminf.   10.95705 (26) obj. 19.4429 iterations 28
# Cbc0038I Pass  10: suminf.   10.05705 (24) obj. 19.4429 iterations 22
# Cbc0038I Pass  11: suminf.    9.55705 (20) obj. 19.4429 iterations 43
# Cbc0038I Pass  12: suminf.    9.55705 (20) obj. 19.4429 iterations 9
# Cbc0038I Pass  13: suminf.    7.94057 (22) obj. 19.4429 iterations 42
# Cbc0038I Pass  14: suminf.    5.75337 (32) obj. 19.4429 iterations 27
# Cbc0038I Pass  15: suminf.    5.47940 (30) obj. 19.4429 iterations 6
# Cbc0038I Pass  16: suminf.   10.55705 (22) obj. 19.4429 iterations 104
# Cbc0038I Pass  17: suminf.   10.55705 (22) obj. 19.4429 iterations 19
# Cbc0038I Pass  18: suminf.   10.55705 (22) obj. 19.4429 iterations 28
# Cbc0038I Pass  19: suminf.   10.55705 (22) obj. 19.4429 iterations 20
# Cbc0038I Pass  20: suminf.    9.55705 (20) obj. 19.4429 iterations 58
# Cbc0038I Pass  21: suminf.    9.55705 (20) obj. 19.4429 iterations 12
# Cbc0038I Pass  22: suminf.    9.55705 (20) obj. 19.4429 iterations 29
# Cbc0038I Pass  23: suminf.   11.57987 (32) obj. 19.4429 iterations 54
# Cbc0038I Pass  24: suminf.    9.55705 (20) obj. 19.4429 iterations 26
# Cbc0038I Pass  25: suminf.    9.55705 (20) obj. 19.4429 iterations 8
# Cbc0038I Pass  26: suminf.    9.55705 (20) obj. 19.4429 iterations 44
# Cbc0038I Pass  27: suminf.    9.55705 (20) obj. 19.4429 iterations 30
# Cbc0038I Pass  28: suminf.    8.77987 (23) obj. 19.4429 iterations 42
# Cbc0038I Pass  29: suminf.    8.77987 (23) obj. 19.4429 iterations 14
# Cbc0038I Pass  30: suminf.    9.55705 (20) obj. 19.4429 iterations 49
# Cbc0038I Pass  31: suminf.    9.55705 (20) obj. 19.4429 iterations 12
# Cbc0038I Pass  32: suminf.    9.12529 (23) obj. 19.4429 iterations 36
# Cbc0038I Pass  33: suminf.    9.12529 (23) obj. 19.4429 iterations 16
# Cbc0038I Pass  34: suminf.    9.55705 (20) obj. 19.4429 iterations 62
# Cbc0038I Pass  35: suminf.    9.55705 (20) obj. 19.4429 iterations 20
# Cbc0038I Pass  36: suminf.    8.77987 (23) obj. 19.4429 iterations 31
# Cbc0038I Pass  37: suminf.    8.77987 (23) obj. 19.4429 iterations 12
# Cbc0038I Pass  38: suminf.    8.65293 (30) obj. 19.4429 iterations 25
# Cbc0038I Pass  39: suminf.    8.65293 (30) obj. 19.4429 iterations 6
# Cbc0038I Pass  40: suminf.   10.55705 (22) obj. 19.4429 iterations 76
# Cbc0038I Pass  41: suminf.   10.55705 (22) obj. 19.4429 iterations 28
# Cbc0038I Pass  42: suminf.   10.55705 (22) obj. 19.4429 iterations 42
# Cbc0038I Pass  43: suminf.   10.55705 (22) obj. 19.4429 iterations 23
# Cbc0038I Pass  44: suminf.    9.66846 (30) obj. 19.4429 iterations 37
# Cbc0038I Pass  45: suminf.    9.66846 (30) obj. 19.4429 iterations 8
# Cbc0038I Pass  46: suminf.    9.66846 (30) obj. 19.4429 iterations 12
# Cbc0038I Pass  47: suminf.   10.55705 (22) obj. 19.4429 iterations 64
# Cbc0038I Pass  48: suminf.   10.55705 (22) obj. 19.4429 iterations 14
# Cbc0038I Pass  49: suminf.   10.55705 (22) obj. 19.4429 iterations 44
# Cbc0038I Pass  50: suminf.   10.55705 (22) obj. 19.4429 iterations 19
# Cbc0038I Pass  51: suminf.   10.55705 (22) obj. 19.4429 iterations 23
# Cbc0038I Pass  52: suminf.    7.66947 (33) obj. 19.4429 iterations 41
# Cbc0038I Pass  53: suminf.    7.66947 (33) obj. 19.4429 iterations 13
# Cbc0038I Pass  54: suminf.   10.05705 (26) obj. 19.4429 iterations 48
# Cbc0038I Pass  55: suminf.    9.55705 (20) obj. 19.4429 iterations 20
# Cbc0038I Pass  56: suminf.    9.55705 (20) obj. 19.4429 iterations 18
# Cbc0038I Pass  57: suminf.    9.55705 (20) obj. 19.4429 iterations 48
# Cbc0038I Pass  58: suminf.   10.55705 (22) obj. 19.4429 iterations 35
# Cbc0038I Pass  59: suminf.   10.55705 (22) obj. 19.4429 iterations 13
# Cbc0038I Pass  60: suminf.    9.66846 (30) obj. 19.4429 iterations 39
# Cbc0038I Pass  61: suminf.    9.66846 (30) obj. 19.4429 iterations 8
# Cbc0038I Pass  62: suminf.    5.47940 (30) obj. 19.4429 iterations 59
# Cbc0038I Pass  63: suminf.    5.47940 (30) obj. 19.4429 iterations 14
# Cbc0038I Pass  64: suminf.   10.55705 (22) obj. 19.4429 iterations 62
# Cbc0038I Pass  65: suminf.   10.55705 (22) obj. 19.4429 iterations 16
# Cbc0038I Pass  66: suminf.    9.55705 (20) obj. 19.4429 iterations 57
# Cbc0038I Pass  67: suminf.    9.55705 (20) obj. 19.4429 iterations 22
# Cbc0038I Pass  68: suminf.    8.18748 (30) obj. 19.4429 iterations 45
# Cbc0038I Pass  69: suminf.    8.01823 (32) obj. 19.4429 iterations 13
# Cbc0038I Pass  70: suminf.    7.38352 (30) obj. 19.4429 iterations 15
# Cbc0038I Pass  71: suminf.    7.38352 (30) obj. 19.4429 iterations 9
# Cbc0038I Pass  72: suminf.   10.55705 (22) obj. 19.4429 iterations 72
# Cbc0038I Pass  73: suminf.   10.55705 (22) obj. 19.4429 iterations 22
# Cbc0038I Pass  74: suminf.   10.55705 (22) obj. 19.4429 iterations 30
# Cbc0038I Pass  75: suminf.   10.55705 (22) obj. 19.4429 iterations 21
# Cbc0038I Pass  76: suminf.    9.66846 (30) obj. 19.4429 iterations 64
# Cbc0038I Pass  77: suminf.    9.66846 (30) obj. 19.4429 iterations 12
# Cbc0038I Pass  78: suminf.    9.37227 (30) obj. 19.4429 iterations 62
# Cbc0038I Pass  79: suminf.    9.37227 (30) obj. 19.4429 iterations 12
# Cbc0038I Pass  80: suminf.   10.55705 (22) obj. 19.4429 iterations 114
# Cbc0038I Pass  81: suminf.   10.55705 (22) obj. 19.4429 iterations 31
# Cbc0038I Pass  82: suminf.   10.55705 (22) obj. 19.4429 iterations 62
# Cbc0038I Pass  83: suminf.   10.55705 (22) obj. 19.4429 iterations 20
# Cbc0038I Pass  84: suminf.   10.55705 (22) obj. 19.4429 iterations 18
# Cbc0038I Pass  85: suminf.   10.55705 (22) obj. 19.4429 iterations 31
# Cbc0038I Pass  86: suminf.   10.55705 (22) obj. 19.4429 iterations 26
# Cbc0038I Pass  87: suminf.   10.55705 (22) obj. 19.4429 iterations 30
# Cbc0038I Pass  88: suminf.   10.55705 (22) obj. 19.4429 iterations 36
# Cbc0038I Pass  89: suminf.    9.55705 (20) obj. 19.4429 iterations 45
# Cbc0038I Pass  90: suminf.    9.55705 (20) obj. 19.4429 iterations 25
# Cbc0038I Pass  91: suminf.    9.55705 (20) obj. 19.4429 iterations 31
# Cbc0038I Pass  92: suminf.    9.28152 (29) obj. 19.4429 iterations 84
# Cbc0038I Pass  93: suminf.    6.30740 (33) obj. 19.4429 iterations 20
# Cbc0038I Pass  94: suminf.    5.47940 (30) obj. 19.4429 iterations 13
# Cbc0038I Pass  95: suminf.   10.55705 (22) obj. 19.4429 iterations 35
# Cbc0038I Pass  96: suminf.    9.15402 (30) obj. 19.4429 iterations 31
# Cbc0038I Pass  97: suminf.    9.15402 (30) obj. 19.4429 iterations 10
# Cbc0038I Pass  98: suminf.   10.55705 (22) obj. 19.4429 iterations 44
# Cbc0038I Pass  99: suminf.   10.55705 (22) obj. 19.4429 iterations 37
# Cbc0038I Pass 100: suminf.   10.55705 (22) obj. 19.4429 iterations 40
# Cbc0038I Pass 101: suminf.   10.55705 (22) obj. 19.4429 iterations 12
# Cbc0038I Pass 102: suminf.    9.56973 (30) obj. 19.4429 iterations 39
# Cbc0038I Pass 103: suminf.    9.56973 (30) obj. 19.4429 iterations 16
# Cbc0038I Pass 104: suminf.   10.55705 (22) obj. 19.4429 iterations 33
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 94 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 151 rows 180 columns, reduced to 151 rows 86 columns - 71 fixed gives 8, 13 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I After 0.10 seconds - Feasibility pump exiting with objective of 21 - took 0.08 seconds
# Cbc0012I Integer solution of 21 found by feasibility pump after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0038I Full problem 151 rows 180 columns, reduced to 151 rows 44 columns - 31 fixed gives 3, 4 - ok now
# Cbc0031I 32 added rows had average density of 39.375
# Cbc0013I At root node, 32 cuts changed objective from 14.428571 to 18.666653 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (6 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1016 row cuts average 163.1 elements, 0 column cuts (0 active)  in 0.068 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 43 row cuts average 95.4 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 21 best solution, best possible 18.666653 (0.51 seconds)
# Cbc0016I Integer solution of 20 found by strong branching after 7903 iterations and 7 nodes (0.65 seconds)
# Cbc0001I Search completed - best objective 20, took 8585 iterations and 14 nodes (0.69 seconds)
# Cbc0032I Strong branching done 316 times (7659 iterations), fathomed 5 nodes and fixed 1 variables
# Cbc0035I Maximum depth 5, 487 variables fixed on reduced cost
# Cuts at root node changed objective from 14.4286 to 18.6667
# Probing was tried 100 times and created 0 cuts of which 6 were active after adding rounds of cuts (0.017 seconds)
# Gomory was tried 130 times and created 1055 cuts of which 0 were active after adding rounds of cuts (0.073 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.037 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 100 times and created 43 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                20.00000000
# Enumerated nodes:               14
# Total iterations:               8585
# Time (CPU seconds):             0.68
# Time (Wallclock seconds):       0.70
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.69   (Wallclock seconds):       0.70
# 1

# %%
LpStatus[model.status]
# Out:
# 'Optimal'

# %%
cnt_node=0
cnt_edge=0
for var in model.variables():
    if var.value() > 0.5:
        #print(f'{var.name}: {var.value()}')
        if var.name[0]=='n':
            cnt_node+=1
        else:
            cnt_edge+=1
            
print(cnt_edge==(total_node-k))
print("No. of vortex needed to cover", len(G.edges)-k, "edges in the graph is", cnt_node)
# Out:
# False
# No. of vortex needed to cover 146 edges in the graph is 20
