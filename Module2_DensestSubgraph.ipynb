# %% [markdown]
# # Densest Subgraph
#
# A subgraph is a graph formed by a set of vertices (and appropriate set of edges) in a given graph. The densest k-subgraph problem is the problem of finding a k-vertex subgraph of a graph with the maximum number of edges.
#
# For example, in the picture below we see a 5-subgraph (or a subgraph with 5 vertices) which happens to also be densest. If we pick any other 5-subgraph in this graph, the number of edges in the subgraph will be less than the one given below.
#
# ![Image of subgraph](https://upload.wikimedia.org/wikipedia/commons/a/ae/Dense_subgraph.png)
#
# In this question, you are asked to use the integer programming formulation to solve for k-densest subgraph of a given graph. For the purpose of answer checking, the densest 4-subgraph for the WS graph in the line below is the subgraph containing node (1,3,4,5).
#
# ### Hint
#
# You might need to define variables for all the nodes and edges. Once one particular edge is "picked", then the nodes that this edges connect must also be picked. For example, we have binary variables: $n_0$, $n_1$ and $e_{(0,1)}$ to indicate whether node 0, 1 and edge(0,1) are picked and included in the subgraph. Clearly, we cannot pick edge(0,1) but not node 0 or 1. One way to implement this constraint is to write:
#
# $n_0 + n_1 \ge 2e_{(0,1)}$

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable, LpMinimize
import pulp

# %%
total_node=30
G = nx.watts_strogatz_graph(n = 30, k = 10, p = 0.4, seed = 2002)

# %%
total_node=8
G=nx.Graph()
for i in range(0, 8):
    G.add_node(i)

G.add_edges_from([(0, 1), (1, 2), (1, 7), (2, 3), (2, 4), (2, 7), (3, 4), (3, 7), (4, 5), (5, 6), (6, 7)])

# %%
plt.figure(figsize=(5, 5))
pos=nx.circular_layout(G)
nx.draw_networkx(G, pos)

# %%
print(G.nodes)
print(G.edges)
print(G.subgraph([1, 2, 3, 4, 7]).number_of_edges())
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]
# [(0, 1), (1, 2), (1, 7), (2, 3), (2, 4), (2, 7), (3, 4), (3, 7), (4, 5), (5, 6), (6, 7)]
# 7

# %%
model=LpProblem(name='densest_subgraph', sense=LpMaximize)
k=9

# %%
x={i: LpVariable(name=f'n{i}', cat='Binary') for i in range(total_node)}
print(x)
y={e: LpVariable(name=f'e{e}', cat='Binary') for index, e in enumerate(G.edges)}
y
# Out:
# {0: n0, 1: n1, 2: n2, 3: n3, 4: n4, 5: n5, 6: n6, 7: n7, 8: n8, 9: n9, 10: n10, 11: n11, 12: n12, 13: n13, 14: n14, 15: n15, 16: n16, 17: n17, 18: n18, 19: n19, 20: n20, 21: n21, 22: n22, 23: n23, 24: n24, 25: n25, 26: n26, 27: n27, 28: n28, 29: n29}
# {(0, 1): e(0,_1),
#  (0, 29): e(0,_29),
#  (0, 2): e(0,_2),
#  (0, 3): e(0,_3),
#  (0, 26): e(0,_26),
#  (0, 25): e(0,_25),
#  (0, 10): e(0,_10),
#  (0, 14): e(0,_14),
#  (0, 19): e(0,_19),
#  (0, 13): e(0,_13),
#  (0, 7): e(0,_7),
#  (1, 2): e(1,_2),
#  (1, 3): e(1,_3),
#  (1, 4): e(1,_4),
#  (1, 28): e(1,_28),
#  (1, 5): e(1,_5),
#  (1, 26): e(1,_26),
#  (1, 11): e(1,_11),
#  (1, 21): e(1,_21),
#  (1, 15): e(1,_15),
#  (1, 29): e(1,_29),
#  (1, 27): e(1,_27),
#  (1, 17): e(1,_17),
#  (2, 3): e(2,_3),
#  (2, 4): e(2,_4),
#  (2, 5): e(2,_5),
#  (2, 29): e(2,_29),
#  (2, 6): e(2,_6),
#  (2, 28): e(2,_28),
#  (2, 7): e(2,_7),
#  (2, 27): e(2,_27),
#  (2, 8): e(2,_8),
#  (2, 10): e(2,_10),
#  (3, 4): e(3,_4),
#  (3, 5): e(3,_5),
#  (3, 6): e(3,_6),
#  (3, 7): e(3,_7),
#  (3, 28): e(3,_28),
#  (3, 23): e(3,_23),
#  (4, 5): e(4,_5),
#  (4, 8): e(4,_8),
#  (4, 17): e(4,_17),
#  (4, 28): e(4,_28),
#  (4, 24): e(4,_24),
#  (4, 10): e(4,_10),
#  (5, 6): e(5,_6),
#  (5, 8): e(5,_8),
#  (5, 10): e(5,_10),
#  (5, 21): e(5,_21),
#  (5, 7): e(5,_7),
#  (5, 17): e(5,_17),
#  (5, 20): e(5,_20),
#  (5, 11): e(5,_11),
#  (5, 15): e(5,_15),
#  (6, 7): e(6,_7),
#  (6, 8): e(6,_8),
#  (6, 9): e(6,_9),
#  (6, 11): e(6,_11),
#  (6, 27): e(6,_27),
#  (6, 22): e(6,_22),
#  (7, 10): e(7,_10),
#  (7, 11): e(7,_11),
#  (7, 16): e(7,_16),
#  (7, 9): e(7,_9),
#  (7, 15): e(7,_15),
#  (7, 24): e(7,_24),
#  (7, 26): e(7,_26),
#  (8, 11): e(8,_11),
#  (8, 13): e(8,_13),
#  (8, 25): e(8,_25),
#  (8, 17): e(8,_17),
#  (8, 29): e(8,_29),
#  (8, 18): e(8,_18),
#  (9, 11): e(9,_11),
#  (9, 13): e(9,_13),
#  (9, 14): e(9,_14),
#  (9, 24): e(9,_24),
#  (9, 28): e(9,_28),
#  (9, 29): e(9,_29),
#  (10, 12): e(10,_12),
#  (10, 29): e(10,_29),
#  (11, 12): e(11,_12),
#  (11, 15): e(11,_15),
#  (11, 28): e(11,_28),
#  (11, 13): e(11,_13),
#  (11, 19): e(11,_19),
#  (11, 29): e(11,_29),
#  (12, 13): e(12,_13),
#  (12, 15): e(12,_15),
#  (12, 16): e(12,_16),
#  (12, 17): e(12,_17),
#  (12, 20): e(12,_20),
#  (12, 23): e(12,_23),
#  (13, 14): e(13,_14),
#  (13, 15): e(13,_15),
#  (13, 17): e(13,_17),
#  (13, 18): e(13,_18),
#  (14, 15): e(14,_15),
#  (14, 17): e(14,_17),
#  (14, 18): e(14,_18),
#  (14, 20): e(14,_20),
#  (14, 16): e(14,_16),
#  (15, 16): e(15,_16),
#  (15, 17): e(15,_17),
#  (15, 23): e(15,_23),
#  (15, 28): e(15,_28),
#  (15, 26): e(15,_26),
#  (16, 17): e(16,_17),
#  (16, 19): e(16,_19),
#  (16, 21): e(16,_21),
#  (16, 23): e(16,_23),
#  (16, 26): e(16,_26),
#  (17, 18): e(17,_18),
#  (17, 19): e(17,_19),
#  (17, 21): e(17,_21),
#  (18, 19): e(18,_19),
#  (18, 20): e(18,_20),
#  (18, 21): e(18,_21),
#  (18, 23): e(18,_23),
#  (18, 24): e(18,_24),
#  (19, 20): e(19,_20),
#  (19, 24): e(19,_24),
#  (19, 27): e(19,_27),
#  (19, 29): e(19,_29),
#  (20, 21): e(20,_21),
#  (20, 22): e(20,_22),
#  (20, 25): e(20,_25),
#  (20, 27): e(20,_27),
#  (21, 24): e(21,_24),
#  (21, 26): e(21,_26),
#  (21, 27): e(21,_27),
#  (21, 22): e(21,_22),
#  (22, 23): e(22,_23),
#  (22, 24): e(22,_24),
#  (22, 25): e(22,_25),
#  (22, 26): e(22,_26),
#  (22, 27): e(22,_27),
#  (22, 29): e(22,_29),
#  (23, 24): e(23,_24),
#  (23, 27): e(23,_27),
#  (23, 28): e(23,_28),
#  (24, 26): e(24,_26),
#  (24, 27): e(24,_27),
#  (24, 29): e(24,_29),
#  (25, 27): e(25,_27),
#  (25, 28): e(25,_28),
#  (25, 26): e(25,_26),
#  (26, 27): e(26,_27),
#  (26, 28): e(26,_28),
#  (27, 29): e(27,_29)}

# %%
# constraints
for e in G.edges:
    #print(f'{e[0]} {e[1]}')
    model+=(x[e[0]]+x[e[1]] >= 2*y[(e[0], e[1])], f'constraint{e}')
    #model+=(x[e[0]]+x[e[1]] >= 1, f'constraint{e}')  
model+=lpSum(x[i] for i in range(total_node))==k

# %%
# objective function
model+=lpSum(y[e] for e in G.edges)
model
# Out:
# densest_subgraph:
# MAXIMIZE
# 1*e(0,_1) + 1*e(0,_10) + 1*e(0,_13) + 1*e(0,_14) + 1*e(0,_19) + 1*e(0,_2) + 1*e(0,_25) + 1*e(0,_26) + 1*e(0,_29) + 1*e(0,_3) + 1*e(0,_7) + 1*e(1,_11) + 1*e(1,_15) + 1*e(1,_17) + 1*e(1,_2) + 1*e(1,_21) + 1*e(1,_26) + 1*e(1,_27) + 1*e(1,_28) + 1*e(1,_29) + 1*e(1,_3) + 1*e(1,_4) + 1*e(1,_5) + 1*e(10,_12) + 1*e(10,_29) + 1*e(11,_12) + 1*e(11,_13) + 1*e(11,_15) + 1*e(11,_19) + 1*e(11,_28) + 1*e(11,_29) + 1*e(12,_13) + 1*e(12,_15) + 1*e(12,_16) + 1*e(12,_17) + 1*e(12,_20) + 1*e(12,_23) + 1*e(13,_14) + 1*e(13,_15) + 1*e(13,_17) + 1*e(13,_18) + 1*e(14,_15) + 1*e(14,_16) + 1*e(14,_17) + 1*e(14,_18) + 1*e(14,_20) + 1*e(15,_16) + 1*e(15,_17) + 1*e(15,_23) + 1*e(15,_26) + 1*e(15,_28) + 1*e(16,_17) + 1*e(16,_19) + 1*e(16,_21) + 1*e(16,_23) + 1*e(16,_26) + 1*e(17,_18) + 1*e(17,_19) + 1*e(17,_21) + 1*e(18,_19) + 1*e(18,_20) + 1*e(18,_21) + 1*e(18,_23) + 1*e(18,_24) + 1*e(19,_20) + 1*e(19,_24) + 1*e(19,_27) + 1*e(19,_29) + 1*e(2,_10) + 1*e(2,_27) + 1*e(2,_28) + 1*e(2,_29) + 1*e(2,_3) + 1*e(2,_4) + 1*e(2,_5) + 1*e(2,_6) + 1*e(2,_7) + 1*e(2,_8) + 1*e(20,_21) + 1*e(20,_22) + 1*e(20,_25) + 1*e(20,_27) + 1*e(21,_22) + 1*e(21,_24) + 1*e(21,_26) + 1*e(21,_27) + 1*e(22,_23) + 1*e(22,_24) + 1*e(22,_25) + 1*e(22,_26) + 1*e(22,_27) + 1*e(22,_29) + 1*e(23,_24) + 1*e(23,_27) + 1*e(23,_28) + 1*e(24,_26) + 1*e(24,_27) + 1*e(24,_29) + 1*e(25,_26) + 1*e(25,_27) + 1*e(25,_28) + 1*e(26,_27) + 1*e(26,_28) + 1*e(27,_29) + 1*e(3,_23) + 1*e(3,_28) + 1*e(3,_4) + 1*e(3,_5) + 1*e(3,_6) + 1*e(3,_7) + 1*e(4,_10) + 1*e(4,_17) + 1*e(4,_24) + 1*e(4,_28) + 1*e(4,_5) + 1*e(4,_8) + 1*e(5,_10) + 1*e(5,_11) + 1*e(5,_15) + 1*e(5,_17) + 1*e(5,_20) + 1*e(5,_21) + 1*e(5,_6) + 1*e(5,_7) + 1*e(5,_8) + 1*e(6,_11) + 1*e(6,_22) + 1*e(6,_27) + 1*e(6,_7) + 1*e(6,_8) + 1*e(6,_9) + 1*e(7,_10) + 1*e(7,_11) + 1*e(7,_15) + 1*e(7,_16) + 1*e(7,_24) + 1*e(7,_26) + 1*e(7,_9) + 1*e(8,_11) + 1*e(8,_13) + 1*e(8,_17) + 1*e(8,_18) + 1*e(8,_25) + 1*e(8,_29) + 1*e(9,_11) + 1*e(9,_13) + 1*e(9,_14) + 1*e(9,_24) + 1*e(9,_28) + 1*e(9,_29) + 0
# SUBJECT TO
# constraint(0,_1): - 2 e(0,_1) + n0 + n1 >= 0
#
# constraint(0,_29): - 2 e(0,_29) + n0 + n29 >= 0
#
# constraint(0,_2): - 2 e(0,_2) + n0 + n2 >= 0
#
# constraint(0,_3): - 2 e(0,_3) + n0 + n3 >= 0
#
# constraint(0,_26): - 2 e(0,_26) + n0 + n26 >= 0
#
# constraint(0,_25): - 2 e(0,_25) + n0 + n25 >= 0
#
# constraint(0,_10): - 2 e(0,_10) + n0 + n10 >= 0
#
# constraint(0,_14): - 2 e(0,_14) + n0 + n14 >= 0
#
# constraint(0,_19): - 2 e(0,_19) + n0 + n19 >= 0
#
# constraint(0,_13): - 2 e(0,_13) + n0 + n13 >= 0
#
# constraint(0,_7): - 2 e(0,_7) + n0 + n7 >= 0
#
# constraint(1,_2): - 2 e(1,_2) + n1 + n2 >= 0
#
# constraint(1,_3): - 2 e(1,_3) + n1 + n3 >= 0
#
# constraint(1,_4): - 2 e(1,_4) + n1 + n4 >= 0
#
# constraint(1,_28): - 2 e(1,_28) + n1 + n28 >= 0
#
# constraint(1,_5): - 2 e(1,_5) + n1 + n5 >= 0
#
# constraint(1,_26): - 2 e(1,_26) + n1 + n26 >= 0
#
# constraint(1,_11): - 2 e(1,_11) + n1 + n11 >= 0
#
# constraint(1,_21): - 2 e(1,_21) + n1 + n21 >= 0
#
# constraint(1,_15): - 2 e(1,_15) + n1 + n15 >= 0
#
# constraint(1,_29): - 2 e(1,_29) + n1 + n29 >= 0
#
# constraint(1,_27): - 2 e(1,_27) + n1 + n27 >= 0
#
# constraint(1,_17): - 2 e(1,_17) + n1 + n17 >= 0
#
# constraint(2,_3): - 2 e(2,_3) + n2 + n3 >= 0
#
# constraint(2,_4): - 2 e(2,_4) + n2 + n4 >= 0
#
# constraint(2,_5): - 2 e(2,_5) + n2 + n5 >= 0
#
# constraint(2,_29): - 2 e(2,_29) + n2 + n29 >= 0
#
# constraint(2,_6): - 2 e(2,_6) + n2 + n6 >= 0
#
# constraint(2,_28): - 2 e(2,_28) + n2 + n28 >= 0
#
# constraint(2,_7): - 2 e(2,_7) + n2 + n7 >= 0
#
# constraint(2,_27): - 2 e(2,_27) + n2 + n27 >= 0
#
# constraint(2,_8): - 2 e(2,_8) + n2 + n8 >= 0
#
# constraint(2,_10): - 2 e(2,_10) + n10 + n2 >= 0
#
# constraint(3,_4): - 2 e(3,_4) + n3 + n4 >= 0
#
# constraint(3,_5): - 2 e(3,_5) + n3 + n5 >= 0
#
# constraint(3,_6): - 2 e(3,_6) + n3 + n6 >= 0
#
# constraint(3,_7): - 2 e(3,_7) + n3 + n7 >= 0
#
# constraint(3,_28): - 2 e(3,_28) + n28 + n3 >= 0
#
# constraint(3,_23): - 2 e(3,_23) + n23 + n3 >= 0
#
# constraint(4,_5): - 2 e(4,_5) + n4 + n5 >= 0
#
# constraint(4,_8): - 2 e(4,_8) + n4 + n8 >= 0
#
# constraint(4,_17): - 2 e(4,_17) + n17 + n4 >= 0
#
# constraint(4,_28): - 2 e(4,_28) + n28 + n4 >= 0
#
# constraint(4,_24): - 2 e(4,_24) + n24 + n4 >= 0
#
# constraint(4,_10): - 2 e(4,_10) + n10 + n4 >= 0
#
# constraint(5,_6): - 2 e(5,_6) + n5 + n6 >= 0
#
# constraint(5,_8): - 2 e(5,_8) + n5 + n8 >= 0
#
# constraint(5,_10): - 2 e(5,_10) + n10 + n5 >= 0
#
# constraint(5,_21): - 2 e(5,_21) + n21 + n5 >= 0
#
# constraint(5,_7): - 2 e(5,_7) + n5 + n7 >= 0
#
# constraint(5,_17): - 2 e(5,_17) + n17 + n5 >= 0
#
# constraint(5,_20): - 2 e(5,_20) + n20 + n5 >= 0
#
# constraint(5,_11): - 2 e(5,_11) + n11 + n5 >= 0
#
# constraint(5,_15): - 2 e(5,_15) + n15 + n5 >= 0
#
# constraint(6,_7): - 2 e(6,_7) + n6 + n7 >= 0
#
# constraint(6,_8): - 2 e(6,_8) + n6 + n8 >= 0
#
# constraint(6,_9): - 2 e(6,_9) + n6 + n9 >= 0
#
# constraint(6,_11): - 2 e(6,_11) + n11 + n6 >= 0
#
# constraint(6,_27): - 2 e(6,_27) + n27 + n6 >= 0
#
# constraint(6,_22): - 2 e(6,_22) + n22 + n6 >= 0
#
# constraint(7,_10): - 2 e(7,_10) + n10 + n7 >= 0
#
# constraint(7,_11): - 2 e(7,_11) + n11 + n7 >= 0
#
# constraint(7,_16): - 2 e(7,_16) + n16 + n7 >= 0
#
# constraint(7,_9): - 2 e(7,_9) + n7 + n9 >= 0
#
# constraint(7,_15): - 2 e(7,_15) + n15 + n7 >= 0
#
# constraint(7,_24): - 2 e(7,_24) + n24 + n7 >= 0
#
# constraint(7,_26): - 2 e(7,_26) + n26 + n7 >= 0
#
# constraint(8,_11): - 2 e(8,_11) + n11 + n8 >= 0
#
# constraint(8,_13): - 2 e(8,_13) + n13 + n8 >= 0
#
# constraint(8,_25): - 2 e(8,_25) + n25 + n8 >= 0
#
# constraint(8,_17): - 2 e(8,_17) + n17 + n8 >= 0
#
# constraint(8,_29): - 2 e(8,_29) + n29 + n8 >= 0
#
# constraint(8,_18): - 2 e(8,_18) + n18 + n8 >= 0
#
# constraint(9,_11): - 2 e(9,_11) + n11 + n9 >= 0
#
# constraint(9,_13): - 2 e(9,_13) + n13 + n9 >= 0
#
# constraint(9,_14): - 2 e(9,_14) + n14 + n9 >= 0
#
# constraint(9,_24): - 2 e(9,_24) + n24 + n9 >= 0
#
# constraint(9,_28): - 2 e(9,_28) + n28 + n9 >= 0
#
# constraint(9,_29): - 2 e(9,_29) + n29 + n9 >= 0
#
# constraint(10,_12): - 2 e(10,_12) + n10 + n12 >= 0
#
# constraint(10,_29): - 2 e(10,_29) + n10 + n29 >= 0
#
# constraint(11,_12): - 2 e(11,_12) + n11 + n12 >= 0
#
# constraint(11,_15): - 2 e(11,_15) + n11 + n15 >= 0
#
# constraint(11,_28): - 2 e(11,_28) + n11 + n28 >= 0
#
# constraint(11,_13): - 2 e(11,_13) + n11 + n13 >= 0
#
# constraint(11,_19): - 2 e(11,_19) + n11 + n19 >= 0
#
# constraint(11,_29): - 2 e(11,_29) + n11 + n29 >= 0
#
# constraint(12,_13): - 2 e(12,_13) + n12 + n13 >= 0
#
# constraint(12,_15): - 2 e(12,_15) + n12 + n15 >= 0
#
# constraint(12,_16): - 2 e(12,_16) + n12 + n16 >= 0
#
# constraint(12,_17): - 2 e(12,_17) + n12 + n17 >= 0
#
# constraint(12,_20): - 2 e(12,_20) + n12 + n20 >= 0
#
# constraint(12,_23): - 2 e(12,_23) + n12 + n23 >= 0
#
# constraint(13,_14): - 2 e(13,_14) + n13 + n14 >= 0
#
# constraint(13,_15): - 2 e(13,_15) + n13 + n15 >= 0
#
# constraint(13,_17): - 2 e(13,_17) + n13 + n17 >= 0
#
# constraint(13,_18): - 2 e(13,_18) + n13 + n18 >= 0
#
# constraint(14,_15): - 2 e(14,_15) + n14 + n15 >= 0
#
# constraint(14,_17): - 2 e(14,_17) + n14 + n17 >= 0
#
# constraint(14,_18): - 2 e(14,_18) + n14 + n18 >= 0
#
# constraint(14,_20): - 2 e(14,_20) + n14 + n20 >= 0
#
# constraint(14,_16): - 2 e(14,_16) + n14 + n16 >= 0
#
# constraint(15,_16): - 2 e(15,_16) + n15 + n16 >= 0
#
# constraint(15,_17): - 2 e(15,_17) + n15 + n17 >= 0
#
# constraint(15,_23): - 2 e(15,_23) + n15 + n23 >= 0
#
# constraint(15,_28): - 2 e(15,_28) + n15 + n28 >= 0
#
# constraint(15,_26): - 2 e(15,_26) + n15 + n26 >= 0
#
# constraint(16,_17): - 2 e(16,_17) + n16 + n17 >= 0
#
# constraint(16,_19): - 2 e(16,_19) + n16 + n19 >= 0
#
# constraint(16,_21): - 2 e(16,_21) + n16 + n21 >= 0
#
# constraint(16,_23): - 2 e(16,_23) + n16 + n23 >= 0
#
# constraint(16,_26): - 2 e(16,_26) + n16 + n26 >= 0
#
# constraint(17,_18): - 2 e(17,_18) + n17 + n18 >= 0
#
# constraint(17,_19): - 2 e(17,_19) + n17 + n19 >= 0
#
# constraint(17,_21): - 2 e(17,_21) + n17 + n21 >= 0
#
# constraint(18,_19): - 2 e(18,_19) + n18 + n19 >= 0
#
# constraint(18,_20): - 2 e(18,_20) + n18 + n20 >= 0
#
# constraint(18,_21): - 2 e(18,_21) + n18 + n21 >= 0
#
# constraint(18,_23): - 2 e(18,_23) + n18 + n23 >= 0
#
# constraint(18,_24): - 2 e(18,_24) + n18 + n24 >= 0
#
# constraint(19,_20): - 2 e(19,_20) + n19 + n20 >= 0
#
# constraint(19,_24): - 2 e(19,_24) + n19 + n24 >= 0
#
# constraint(19,_27): - 2 e(19,_27) + n19 + n27 >= 0
#
# constraint(19,_29): - 2 e(19,_29) + n19 + n29 >= 0
#
# constraint(20,_21): - 2 e(20,_21) + n20 + n21 >= 0
#
# constraint(20,_22): - 2 e(20,_22) + n20 + n22 >= 0
#
# constraint(20,_25): - 2 e(20,_25) + n20 + n25 >= 0
#
# constraint(20,_27): - 2 e(20,_27) + n20 + n27 >= 0
#
# constraint(21,_24): - 2 e(21,_24) + n21 + n24 >= 0
#
# constraint(21,_26): - 2 e(21,_26) + n21 + n26 >= 0
#
# constraint(21,_27): - 2 e(21,_27) + n21 + n27 >= 0
#
# constraint(21,_22): - 2 e(21,_22) + n21 + n22 >= 0
#
# constraint(22,_23): - 2 e(22,_23) + n22 + n23 >= 0
#
# constraint(22,_24): - 2 e(22,_24) + n22 + n24 >= 0
#
# constraint(22,_25): - 2 e(22,_25) + n22 + n25 >= 0
#
# constraint(22,_26): - 2 e(22,_26) + n22 + n26 >= 0
#
# constraint(22,_27): - 2 e(22,_27) + n22 + n27 >= 0
#
# constraint(22,_29): - 2 e(22,_29) + n22 + n29 >= 0
#
# constraint(23,_24): - 2 e(23,_24) + n23 + n24 >= 0
#
# constraint(23,_27): - 2 e(23,_27) + n23 + n27 >= 0
#
# constraint(23,_28): - 2 e(23,_28) + n23 + n28 >= 0
#
# constraint(24,_26): - 2 e(24,_26) + n24 + n26 >= 0
#
# constraint(24,_27): - 2 e(24,_27) + n24 + n27 >= 0
#
# constraint(24,_29): - 2 e(24,_29) + n24 + n29 >= 0
#
# constraint(25,_27): - 2 e(25,_27) + n25 + n27 >= 0
#
# constraint(25,_28): - 2 e(25,_28) + n25 + n28 >= 0
#
# constraint(25,_26): - 2 e(25,_26) + n25 + n26 >= 0
#
# constraint(26,_27): - 2 e(26,_27) + n26 + n27 >= 0
#
# constraint(26,_28): - 2 e(26,_28) + n26 + n28 >= 0
#
# constraint(27,_29): - 2 e(27,_29) + n27 + n29 >= 0
#
# _C1: n0 + n1 + n10 + n11 + n12 + n13 + n14 + n15 + n16 + n17 + n18 + n19 + n2
#  + n20 + n21 + n22 + n23 + n24 + n25 + n26 + n27 + n28 + n29 + n3 + n4 + n5
#  + n6 + n7 + n8 + n9 = 9
#
# VARIABLES
# 0 <= e(0,_1) <= 1 Integer
# 0 <= e(0,_10) <= 1 Integer
# 0 <= e(0,_13) <= 1 Integer
# 0 <= e(0,_14) <= 1 Integer
# 0 <= e(0,_19) <= 1 Integer
# 0 <= e(0,_2) <= 1 Integer
# 0 <= e(0,_25) <= 1 Integer
# 0 <= e(0,_26) <= 1 Integer
# 0 <= e(0,_29) <= 1 Integer
# 0 <= e(0,_3) <= 1 Integer
# 0 <= e(0,_7) <= 1 Integer
# 0 <= e(1,_11) <= 1 Integer
# 0 <= e(1,_15) <= 1 Integer
# 0 <= e(1,_17) <= 1 Integer
# 0 <= e(1,_2) <= 1 Integer
# 0 <= e(1,_21) <= 1 Integer
# 0 <= e(1,_26) <= 1 Integer
# 0 <= e(1,_27) <= 1 Integer
# 0 <= e(1,_28) <= 1 Integer
# 0 <= e(1,_29) <= 1 Integer
# 0 <= e(1,_3) <= 1 Integer
# 0 <= e(1,_4) <= 1 Integer
# 0 <= e(1,_5) <= 1 Integer
# 0 <= e(10,_12) <= 1 Integer
# 0 <= e(10,_29) <= 1 Integer
# 0 <= e(11,_12) <= 1 Integer
# 0 <= e(11,_13) <= 1 Integer
# 0 <= e(11,_15) <= 1 Integer
# 0 <= e(11,_19) <= 1 Integer
# 0 <= e(11,_28) <= 1 Integer
# 0 <= e(11,_29) <= 1 Integer
# 0 <= e(12,_13) <= 1 Integer
# 0 <= e(12,_15) <= 1 Integer
# 0 <= e(12,_16) <= 1 Integer
# 0 <= e(12,_17) <= 1 Integer
# 0 <= e(12,_20) <= 1 Integer
# 0 <= e(12,_23) <= 1 Integer
# 0 <= e(13,_14) <= 1 Integer
# 0 <= e(13,_15) <= 1 Integer
# 0 <= e(13,_17) <= 1 Integer
# 0 <= e(13,_18) <= 1 Integer
# 0 <= e(14,_15) <= 1 Integer
# 0 <= e(14,_16) <= 1 Integer
# 0 <= e(14,_17) <= 1 Integer
# 0 <= e(14,_18) <= 1 Integer
# 0 <= e(14,_20) <= 1 Integer
# 0 <= e(15,_16) <= 1 Integer
# 0 <= e(15,_17) <= 1 Integer
# 0 <= e(15,_23) <= 1 Integer
# 0 <= e(15,_26) <= 1 Integer
# 0 <= e(15,_28) <= 1 Integer
# 0 <= e(16,_17) <= 1 Integer
# 0 <= e(16,_19) <= 1 Integer
# 0 <= e(16,_21) <= 1 Integer
# 0 <= e(16,_23) <= 1 Integer
# 0 <= e(16,_26) <= 1 Integer
# 0 <= e(17,_18) <= 1 Integer
# 0 <= e(17,_19) <= 1 Integer
# 0 <= e(17,_21) <= 1 Integer
# 0 <= e(18,_19) <= 1 Integer
# 0 <= e(18,_20) <= 1 Integer
# 0 <= e(18,_21) <= 1 Integer
# 0 <= e(18,_23) <= 1 Integer
# 0 <= e(18,_24) <= 1 Integer
# 0 <= e(19,_20) <= 1 Integer
# 0 <= e(19,_24) <= 1 Integer
# 0 <= e(19,_27) <= 1 Integer
# 0 <= e(19,_29) <= 1 Integer
# 0 <= e(2,_10) <= 1 Integer
# 0 <= e(2,_27) <= 1 Integer
# 0 <= e(2,_28) <= 1 Integer
# 0 <= e(2,_29) <= 1 Integer
# 0 <= e(2,_3) <= 1 Integer
# 0 <= e(2,_4) <= 1 Integer
# 0 <= e(2,_5) <= 1 Integer
# 0 <= e(2,_6) <= 1 Integer
# 0 <= e(2,_7) <= 1 Integer
# 0 <= e(2,_8) <= 1 Integer
# 0 <= e(20,_21) <= 1 Integer
# 0 <= e(20,_22) <= 1 Integer
# 0 <= e(20,_25) <= 1 Integer
# 0 <= e(20,_27) <= 1 Integer
# 0 <= e(21,_22) <= 1 Integer
# 0 <= e(21,_24) <= 1 Integer
# 0 <= e(21,_26) <= 1 Integer
# 0 <= e(21,_27) <= 1 Integer
# 0 <= e(22,_23) <= 1 Integer
# 0 <= e(22,_24) <= 1 Integer
# 0 <= e(22,_25) <= 1 Integer
# 0 <= e(22,_26) <= 1 Integer
# 0 <= e(22,_27) <= 1 Integer
# 0 <= e(22,_29) <= 1 Integer
# 0 <= e(23,_24) <= 1 Integer
# 0 <= e(23,_27) <= 1 Integer
# 0 <= e(23,_28) <= 1 Integer
# 0 <= e(24,_26) <= 1 Integer
# 0 <= e(24,_27) <= 1 Integer
# 0 <= e(24,_29) <= 1 Integer
# 0 <= e(25,_26) <= 1 Integer
# 0 <= e(25,_27) <= 1 Integer
# 0 <= e(25,_28) <= 1 Integer
# 0 <= e(26,_27) <= 1 Integer
# 0 <= e(26,_28) <= 1 Integer
# 0 <= e(27,_29) <= 1 Integer
# 0 <= e(3,_23) <= 1 Integer
# 0 <= e(3,_28) <= 1 Integer
# 0 <= e(3,_4) <= 1 Integer
# 0 <= e(3,_5) <= 1 Integer
# 0 <= e(3,_6) <= 1 Integer
# 0 <= e(3,_7) <= 1 Integer
# 0 <= e(4,_10) <= 1 Integer
# 0 <= e(4,_17) <= 1 Integer
# 0 <= e(4,_24) <= 1 Integer
# 0 <= e(4,_28) <= 1 Integer
# 0 <= e(4,_5) <= 1 Integer
# 0 <= e(4,_8) <= 1 Integer
# 0 <= e(5,_10) <= 1 Integer
# 0 <= e(5,_11) <= 1 Integer
# 0 <= e(5,_15) <= 1 Integer
# 0 <= e(5,_17) <= 1 Integer
# 0 <= e(5,_20) <= 1 Integer
# 0 <= e(5,_21) <= 1 Integer
# 0 <= e(5,_6) <= 1 Integer
# 0 <= e(5,_7) <= 1 Integer
# 0 <= e(5,_8) <= 1 Integer
# 0 <= e(6,_11) <= 1 Integer
# 0 <= e(6,_22) <= 1 Integer
# 0 <= e(6,_27) <= 1 Integer
# 0 <= e(6,_7) <= 1 Integer
# 0 <= e(6,_8) <= 1 Integer
# 0 <= e(6,_9) <= 1 Integer
# 0 <= e(7,_10) <= 1 Integer
# 0 <= e(7,_11) <= 1 Integer
# 0 <= e(7,_15) <= 1 Integer
# 0 <= e(7,_16) <= 1 Integer
# 0 <= e(7,_24) <= 1 Integer
# 0 <= e(7,_26) <= 1 Integer
# 0 <= e(7,_9) <= 1 Integer
# 0 <= e(8,_11) <= 1 Integer
# 0 <= e(8,_13) <= 1 Integer
# 0 <= e(8,_17) <= 1 Integer
# 0 <= e(8,_18) <= 1 Integer
# 0 <= e(8,_25) <= 1 Integer
# 0 <= e(8,_29) <= 1 Integer
# 0 <= e(9,_11) <= 1 Integer
# 0 <= e(9,_13) <= 1 Integer
# 0 <= e(9,_14) <= 1 Integer
# 0 <= e(9,_24) <= 1 Integer
# 0 <= e(9,_28) <= 1 Integer
# 0 <= e(9,_29) <= 1 Integer
# 0 <= n0 <= 1 Integer
# 0 <= n1 <= 1 Integer
# 0 <= n10 <= 1 Integer
# 0 <= n11 <= 1 Integer
# 0 <= n12 <= 1 Integer
# 0 <= n13 <= 1 Integer
# 0 <= n14 <= 1 Integer
# 0 <= n15 <= 1 Integer
# 0 <= n16 <= 1 Integer
# 0 <= n17 <= 1 Integer
# 0 <= n18 <= 1 Integer
# 0 <= n19 <= 1 Integer
# 0 <= n2 <= 1 Integer
# 0 <= n20 <= 1 Integer
# 0 <= n21 <= 1 Integer
# 0 <= n22 <= 1 Integer
# 0 <= n23 <= 1 Integer
# 0 <= n24 <= 1 Integer
# 0 <= n25 <= 1 Integer
# 0 <= n26 <= 1 Integer
# 0 <= n27 <= 1 Integer
# 0 <= n28 <= 1 Integer
# 0 <= n29 <= 1 Integer
# 0 <= n3 <= 1 Integer
# 0 <= n4 <= 1 Integer
# 0 <= n5 <= 1 Integer
# 0 <= n6 <= 1 Integer
# 0 <= n7 <= 1 Integer
# 0 <= n8 <= 1 Integer
# 0 <= n9 <= 1 Integer

# %%
model.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/panithi/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a07b3a7412544f798239a6bd13b1ff39-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/a07b3a7412544f798239a6bd13b1ff39-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 156 COLUMNS
# At line 1147 RHS
# At line 1299 BOUNDS
# At line 1480 ENDATA
# Problem MODEL has 151 rows, 180 columns and 480 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 54.5 - 0.01 seconds
# Cgl0004I processed model has 151 rows, 180 columns (180 integer (180 of which binary)) and 480 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 71 integers unsatisfied sum - 35.5
# Cbc0038I Solution found of -19
# Cbc0038I Before mini branch and bound, 109 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 151 rows 180 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -23.4499
# Cbc0038I Pass   1: suminf.    4.44991 (9) obj. -23.4499 iterations 128
# Cbc0038I Pass   2: suminf.    4.50000 (9) obj. -23.5 iterations 9
# Cbc0038I Pass   3: suminf.   13.00000 (26) obj. -27 iterations 45
# Cbc0038I Pass   4: suminf.    7.44991 (15) obj. -23.4499 iterations 53
# Cbc0038I Pass   5: suminf.    7.44991 (15) obj. -23.4499 iterations 4
# Cbc0038I Pass   6: suminf.    7.50000 (15) obj. -23.5 iterations 20
# Cbc0038I Pass   7: suminf.   13.44991 (27) obj. -23.4499 iterations 33
# Cbc0038I Pass   8: suminf.   10.44991 (21) obj. -23.4499 iterations 37
# Cbc0038I Pass   9: suminf.   10.44991 (21) obj. -23.4499 iterations 0
# Cbc0038I Pass  10: suminf.   10.44991 (21) obj. -23.4499 iterations 5
# Cbc0038I Pass  11: suminf.   11.44991 (23) obj. -23.4499 iterations 56
# Cbc0038I Pass  12: suminf.   11.44991 (23) obj. -23.4499 iterations 42
# Cbc0038I Pass  13: suminf.   11.44991 (23) obj. -23.4499 iterations 9
# Cbc0038I Pass  14: suminf.   14.50000 (33) obj. -23.4499 iterations 53
# Cbc0038I Pass  15: suminf.   13.44991 (27) obj. -23.4499 iterations 41
# Cbc0038I Pass  16: suminf.   13.44991 (27) obj. -23.4499 iterations 1
# Cbc0038I Pass  17: suminf.   13.50000 (27) obj. -23.5 iterations 21
# Cbc0038I Pass  18: suminf.   14.44991 (29) obj. -23.4499 iterations 44
# Cbc0038I Pass  19: suminf.   14.44991 (29) obj. -23.4499 iterations 44
# Cbc0038I Pass  20: suminf.   14.44991 (29) obj. -23.4499 iterations 6
# Cbc0038I Pass  21: suminf.   14.55009 (34) obj. -23.4499 iterations 61
# Cbc0038I Pass  22: suminf.   12.44991 (25) obj. -23.4499 iterations 45
# Cbc0038I Pass  23: suminf.   12.44991 (25) obj. -23.4499 iterations 6
# Cbc0038I Pass  24: suminf.   12.44991 (25) obj. -23.4499 iterations 11
# Cbc0038I Pass  25: suminf.   13.00000 (26) obj. -24 iterations 41
# Cbc0038I Pass  26: suminf.   11.44991 (23) obj. -23.4499 iterations 37
# Cbc0038I Pass  27: suminf.   11.44991 (23) obj. -23.4499 iterations 0
# Cbc0038I Pass  28: suminf.   11.44991 (23) obj. -23.4499 iterations 5
# Cbc0038I Pass  29: suminf.   13.44991 (31) obj. -23.4499 iterations 44
# Cbc0038I Pass  30: suminf.   11.44991 (23) obj. -23.4499 iterations 38
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 39 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 151 rows 180 columns, reduced to 110 rows 127 columns - 8 fixed gives 82, 94 - ok now
# Cbc0038I Full problem 151 rows 180 columns, reduced to 62 rows 74 columns
# Cbc0038I Mini branch and bound improved solution from -19 to -21 (0.09 seconds)
# Cbc0038I Round again with cutoff of -29.6599
# Cbc0038I Pass  30: suminf.   10.65993 (22) obj. -29.6599 iterations 23
# Cbc0038I Pass  31: suminf.   10.65993 (22) obj. -29.6599 iterations 4
# Cbc0038I Pass  32: suminf.   13.34007 (27) obj. -29.6599 iterations 31
# Cbc0038I Pass  33: suminf.   12.65993 (26) obj. -29.6599 iterations 33
# Cbc0038I Pass  34: suminf.   12.65993 (26) obj. -29.6599 iterations 4
# Cbc0038I Pass  35: suminf.   17.65993 (36) obj. -29.6599 iterations 44
# Cbc0038I Pass  36: suminf.   15.65993 (32) obj. -29.6599 iterations 38
# Cbc0038I Pass  37: suminf.   15.65993 (32) obj. -29.6599 iterations 1
# Cbc0038I Pass  38: suminf.   15.65993 (32) obj. -29.6599 iterations 1
# Cbc0038I Pass  39: suminf.   16.65993 (34) obj. -29.6599 iterations 52
# Cbc0038I Pass  40: suminf.   16.65993 (34) obj. -29.6599 iterations 51
# Cbc0038I Pass  41: suminf.   16.65993 (34) obj. -29.6599 iterations 5
# Cbc0038I Pass  42: suminf.   14.65993 (30) obj. -29.6599 iterations 61
# Cbc0038I Pass  43: suminf.   13.65993 (28) obj. -29.6599 iterations 53
# Cbc0038I Pass  44: suminf.   13.65993 (28) obj. -29.6599 iterations 0
# Cbc0038I Pass  45: suminf.   13.65993 (28) obj. -29.6599 iterations 3
# Cbc0038I Pass  46: suminf.   12.65993 (26) obj. -29.6599 iterations 48
# Cbc0038I Pass  47: suminf.   11.65993 (24) obj. -29.6599 iterations 36
# Cbc0038I Pass  48: suminf.   11.65993 (24) obj. -29.6599 iterations 0
# Cbc0038I Pass  49: suminf.   11.65993 (24) obj. -29.6599 iterations 7
# Cbc0038I Pass  50: suminf.   18.65993 (38) obj. -29.6599 iterations 46
# Cbc0038I Pass  51: suminf.   17.65993 (36) obj. -29.6599 iterations 45
# Cbc0038I Pass  52: suminf.   17.65993 (36) obj. -29.6599 iterations 0
# Cbc0038I Pass  53: suminf.   17.65993 (36) obj. -29.6599 iterations 8
# Cbc0038I Pass  54: suminf.   17.81986 (42) obj. -29.6599 iterations 50
# Cbc0038I Pass  55: suminf.   17.34007 (35) obj. -29.6599 iterations 39
# Cbc0038I Pass  56: suminf.   16.65993 (34) obj. -29.6599 iterations 11
# Cbc0038I Pass  57: suminf.   16.65993 (34) obj. -29.6599 iterations 3
# Cbc0038I Pass  58: suminf.   14.98989 (36) obj. -29.6599 iterations 48
# Cbc0038I Pass  59: suminf.   13.65993 (28) obj. -29.6599 iterations 29
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 46 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 151 rows 180 columns, reduced to 103 rows 117 columns - 18 fixed gives 75, 85 - ok now
# Cbc0038I Full problem 151 rows 180 columns, reduced to 50 rows 60 columns
# Cbc0038I Mini branch and bound did not improve solution (0.11 seconds)
# Cbc0038I After 0.11 seconds - Feasibility pump exiting with objective of -21 - took 0.07 seconds
# Cbc0012I Integer solution of -21 found by feasibility pump after 0 iterations and 0 nodes (0.11 seconds)
# Cbc0038I Full problem 151 rows 180 columns, reduced to 8 rows 9 columns
# Cbc0031I 59 added rows had average density of 43.457627
# Cbc0013I At root node, 59 cuts changed objective from -54.5 to -41.231507 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 10362 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.082 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2463 row cuts average 146.4 elements, 0 column cuts (0 active)  in 0.398 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 2797 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.056 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.127 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1440 row cuts average 6.4 elements, 0 column cuts (0 active)  in 0.053 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -21 best solution, best possible -41.231507 (1.76 seconds)
# Cbc0004I Integer solution of -23 found after 19852 iterations and 172 nodes (4.96 seconds)
# Cbc0004I Integer solution of -25 found after 22178 iterations and 212 nodes (5.32 seconds)
# Cbc0038I Full problem 151 rows 180 columns, reduced to 113 rows 141 columns - 6 fixed gives 110, 135 - still too large
# Cbc0038I Full problem 151 rows 180 columns, reduced to 110 rows 135 columns - too large
# Cbc0010I After 1000 nodes, 225 on tree, -25 best solution, best possible -41.231507 (36.08 seconds)
# Cbc0010I After 2000 nodes, 112 on tree, -25 best solution, best possible -41.231507 (49.42 seconds)
# Cbc0010I After 3000 nodes, 48 on tree, -25 best solution, best possible -41.231507 (53.18 seconds)
# Cbc0010I After 4000 nodes, 21 on tree, -25 best solution, best possible -41.231507 (57.07 seconds)
# Cbc0010I After 5000 nodes, 24 on tree, -25 best solution, best possible -41.231507 (62.63 seconds)
# Cbc0010I After 6000 nodes, 13 on tree, -25 best solution, best possible -41.231507 (66.22 seconds)
# Cbc0004I Integer solution of -26 found after 228887 iterations and 6475 nodes (68.26 seconds)
# Cbc0010I After 7000 nodes, 16 on tree, -26 best solution, best possible -41.231507 (70.92 seconds)
# Cbc0010I After 8000 nodes, 30 on tree, -26 best solution, best possible -41.231507 (75.18 seconds)
# Cbc0010I After 9000 nodes, 5 on tree, -26 best solution, best possible -41.231507 (78.96 seconds)
# Cbc0010I After 10000 nodes, 16 on tree, -26 best solution, best possible -36.862206 (84.08 seconds)
# Cbc0010I After 11000 nodes, 13 on tree, -26 best solution, best possible -36.862206 (88.15 seconds)
# Cbc0001I Search completed - best objective -26, took 2108227 iterations and 213387 nodes (88.59 seconds)
# Cbc0032I Strong branching done 25882 times (293968 iterations), fathomed 297 nodes and fixed 810 variables
# Cbc0041I Maximum depth 49, 1677 variables fixed on reduced cost (complete fathoming 168 times, 202305 nodes taking 1750858 iterations)
# Cuts at root node changed objective from -54.5 to -41.2315
# Probing was tried 18056 times and created 351050 cuts of which 0 were active after adding rounds of cuts (6.001 seconds)
# Gomory was tried 17896 times and created 43292 cuts of which 0 were active after adding rounds of cuts (7.749 seconds)
# Knapsack was tried 17935 times and created 90383 cuts of which 0 were active after adding rounds of cuts (6.482 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.015 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.127 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# TwoMirCuts was tried 17896 times and created 124191 cuts of which 0 were active after adding rounds of cuts (2.532 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 1028 times and created 82288 cuts of which 0 were active after adding rounds of cuts (1.466 seconds)
#
# Result - Optimal solution found
#
# Objective value:                26.00000000
# Enumerated nodes:               213387
# Total iterations:               2108227
# Time (CPU seconds):             87.90
# Time (Wallclock seconds):       88.61
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       87.91   (Wallclock seconds):       88.61
# 1

# %%
LpStatus[model.status]
# Out:
# 'Optimal'

# %%
cnt_edge=0
for var in model.variables():
    if var.value() > 0.5:
        print(f'{var.name}: {var.value()}')
        if var.name[0]=='e':
            cnt_edge+=1
            
print("No. of edges in ", k, "- densest subgraph is ", cnt_edge)
# Out:
# e(0,_1): 1.0
# e(0,_10): 1.0
# e(0,_2): 1.0
# e(0,_29): 1.0
# e(0,_3): 1.0
# e(0,_7): 1.0
# e(1,_2): 1.0
# e(1,_29): 1.0
# e(1,_3): 1.0
# e(1,_4): 1.0
# e(1,_5): 1.0
# e(10,_29): 1.0
# e(2,_10): 1.0
# e(2,_29): 1.0
# e(2,_3): 1.0
# e(2,_4): 1.0
# e(2,_5): 1.0
# e(2,_7): 1.0
# e(3,_4): 1.0
# e(3,_5): 1.0
# e(3,_7): 1.0
# e(4,_10): 1.0
# e(4,_5): 1.0
# e(5,_10): 1.0
# e(5,_7): 1.0
# e(7,_10): 1.0
# n0: 1.0
# n1: 1.0
# n10: 1.0
# n2: 1.0
# n29: 1.0
# n3: 1.0
# n4: 1.0
# n5: 1.0
# n7: 1.0
# No. of edges in  9 - densest subgraph is  26

# %%
plt.figure(figsize=(7, 7))

color_map=[]
for i in range(len(model.variables())):
    if model.variables()[i].name[0]=='n' and model.variables()[i].value() > 0.5:
        color_map.append("#dd4b39")
    elif model.variables()[i].name[0]=='n':
        color_map.append("#96DBFF")

pos=nx.circular_layout(G)
nx.draw_networkx(G, pos, with_labels=True, node_color=color_map)
